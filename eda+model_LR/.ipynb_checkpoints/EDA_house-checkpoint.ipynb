# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
house_df=pd.read_csv(r"C:\Users\NTCUONG\notebook\house_training.csv")
house_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_df.iloc[:,1:].describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
numeric_df=house_df.iloc[:,1:].select_dtypes(include=['int64','float64'])
cor=numeric_df.corr()
plt.matshow(numeric_df.corr())

# %%
sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >

# %%
numeric_df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
sns.histplot(data=numeric_df,x='SalePrice')
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
numeric_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   LotFrontage    1201 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   OverallQual    1460 non-null   int64
#  4   OverallCond    1460 non-null   int64
#  5   YearBuilt      1460 non-null   int64
#  6   YearRemodAdd   1460 non-null   int64
#  7   MasVnrArea     1452 non-null   float64
#  8   BsmtFinSF1     1460 non-null   int64
#  9   BsmtFinSF2     1460 non-null   int64
#  10  BsmtUnfSF      1460 non-null   int64
#  11  TotalBsmtSF    1460 non-null   int64
#  12  1stFlrSF       1460 non-null   int64
#  13  2ndFlrSF       1460 non-null   int64
#  14  LowQualFinSF   1460 non-null   int64
#  15  GrLivArea      1460 non-null   int64
#  16  BsmtFullBath   1460 non-null   int64
#  17  BsmtHalfBath   1460 non-null   int64
# ...

# %%
c = numeric_df.columns
c = list(c)
fig,ax = plt.subplots(nrows=6,ncols=6,figsize=(50,25))
count=0
for i in range(6):
    for j in range(6):
        sns.histplot(data=numeric_df.iloc[:,:-1],x=c[count],ax=ax[i][j])
        count+=1

# %%
max_cor=max(cor.iloc[:-1,-1])
cor.loc[cor["SalePrice"] == max_cor]
# Out:
#              MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# OverallQual    0.032628     0.251646  0.105806          1.0    -0.091932
#
#              YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  \
# OverallQual   0.572323      0.550684    0.411876    0.239666   -0.059119  ...
#
#              WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# OverallQual    0.238923     0.308819      -0.113937   0.030371     0.064886
#
#              PoolArea   MiscVal    MoSold    YrSold  SalePrice
# OverallQual  0.065166 -0.031406  0.070815 -0.027347   0.790982
#
# [1 rows x 37 columns]

# %%
cor.sort_values("SalePrice",ascending=False).head(10)
# Out:
#               MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# SalePrice      -0.084284     0.351799  0.263843     0.790982    -0.077856
# OverallQual     0.032628     0.251646  0.105806     1.000000    -0.091932
# GrLivArea       0.074853     0.402797  0.263116     0.593007    -0.079686
# GarageCars     -0.040110     0.285691  0.154871     0.600671    -0.185758
# GarageArea     -0.098672     0.344997  0.180403     0.562022    -0.151521
# TotalBsmtSF    -0.238518     0.392075  0.260833     0.537808    -0.171098
# 1stFlrSF       -0.251758     0.457181  0.299475     0.476224    -0.144203
# FullBath        0.131608     0.198769  0.126031     0.550600    -0.194149
# TotRmsAbvGrd    0.040380     0.352096  0.190015     0.427452    -0.057583
# YearBuilt       0.027850     0.123349  0.014228     0.572323    -0.375983
#
#               YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# SalePrice      0.522897      0.507101    0.477493    0.386420   -0.011378
# ...
