# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score
import pandas as pd
from sklearn.metrics.pairwise import rbf_kernel,polynomial_kernel,linear_kernel,sigmoid_kernel

# %%
df=pd.read_csv(r"C:\Users\NTCUONG\notebook\cnt-first-project\feature_selection\training1.csv")
df
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# 4             60         3         84.0    14260       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0     7917       1         3
# 1456          20         3         85.0    13175       1         3
# 1457          70         3         66.0     9042       1         3
# 1458          20         3         68.0     9717       1         3
# 1459          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  3SsnPorch  \
# 0               3          0          4          0  ...          0
# 1               3          0          2          0  ...          0
# 2               3          0          4          0  ...          0
# 3               3          0          0          0  ...          0
# 4               3          0          2          0  ...          0
# ...           ...        ...        ...        ...  ...        ...
# 1455            3          0          4          0  ...          0
# 1456            3          0          4          0  ...          0
# 1457            3          0          4          0  ...          0
# 1458            3          0          4          0  ...          0
# 1459            3          0          4          0  ...          0
#
#       ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# 0               0         0        0       2    2008         8              4
# 1               0         0        0       5    2007         8              4
# 2               0         0        0       9    2008         8              4
# 3               0         0        0       2    2006         8              0
# 4               0         0        0      12    2008         8              4
# ...           ...       ...      ...     ...     ...       ...            ...
# 1455            0         0        0       8    2007         8              4
# 1456            0         0        0       2    2010         8              4
# 1457            0         0     2500       5    2010         8              4
# 1458            0         0        0       4    2010         8              4
# 1459            0         0        0       6    2008         8              4
#
#       Ageofhouse  SalePrice
# 0              5     208500
# 1             31     181500
# 2              7     223500
# 3             91     140000
# 4              8     250000
# ...          ...        ...
# 1455           8     175000
# 1456          32     210000
# 1457          69     266500
# 1458          60     142125
# 1459          43     147500
#
# [1460 rows x 75 columns]

# %%
model=SVR()
param_grid={
    "kernel":['rbf','poly'],
    "C":[0.001, 0.005, 0.01, 0.1, 0.15],
    "epsilon":[0.1, 0.3 , 0.15, 0.01, 0.5]
}
grid_search=GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring="r2")
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,:-1],df.iloc[:,-1],test_size=0.2,random_state=42)
grid_search.fit(X_train,y_train)
print(f'Best parameters: {grid_search.best_params_}')

# Dự đoán trên tập kiểm tra
y_pred = grid_search.predict(X_test)

# Tính toán lỗi MSE
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {r2}')
# Out:
# Best parameters: {'C': 0.15, 'epsilon': 0.1, 'kernel': 'poly'}
# Mean Squared Error: -0.02380002152284222
