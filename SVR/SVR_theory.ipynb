# %% [markdown]
# ### Giới thiệu

# %% [markdown]
# ![image.png](attachment:c56fb715-30c1-4ffb-800c-cc488f1397ea.png)

# %% [markdown]
# ### SVR là mô hình hồi quy lấy ý tưởng từ mô hình phân loại SVM, mục đích của mô hình là tìm được đường tối ưu đi qua các điểm dữ liệu sao cho lỗi là nhỏ nhất, đồng thời số điểm dữ liệu nằm trong margin là lớn nhất

# %% [markdown]
# ![image.png](attachment:fab2744f-514c-4f9d-992c-97038ba6dcb3.png)

# %% [markdown]
# ### Kernal

# %% [markdown]
# ### Là một ánh xạ để biến không gian của dữ liệu thành một không gian mới để dễ dàng tìm được siêu phẳng của mô hình

# %% [markdown]
# ![image.png](attachment:f9967377-042a-4f1d-bfe9-c1bde37b552d.png)
