# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("StatisticModel.csv")
df
# Out:
#      Model  feature_selection  NOF        Scaler        Encoder  \
# 0      SVR  VarianceThreshold  100     Nomalizer   LabelEncoder
# 1      SVR  VarianceThreshold  105     Nomalizer   LabelEncoder
# 2      SVR  VarianceThreshold  110     Nomalizer   LabelEncoder
# 3      SVR  VarianceThreshold  115     Nomalizer   LabelEncoder
# 4      SVR  VarianceThreshold  120     Nomalizer   LabelEncoder
# ...    ...                ...  ...           ...            ...
# 1128   SVR                UFS   95  Minmaxscaler  OnehotEncoder
# 1129   SVR                UFS  100  Minmaxscaler  OnehotEncoder
# 1130   SVR                UFS  105  Minmaxscaler  OnehotEncoder
# 1131   SVR                UFS  110  Minmaxscaler  OnehotEncoder
# 1132   SVR                UFS  115  Minmaxscaler  OnehotEncoder
#
#             Imputer        R2           MAE
# 0     SimpleImputer -0.024790  59559.698541
# 1     SimpleImputer -0.024790  59559.698541
# 2     SimpleImputer -0.024790  59559.698541
# 3     SimpleImputer -0.024790  59559.698541
# 4     SimpleImputer -0.024790  59559.698541
# ...             ...       ...           ...
# 1128     KnnImputer -0.023994  59517.010509
# 1129     KnnImputer -0.024017  59518.243655
# 1130     KnnImputer -0.024033  59519.346637
# 1131     KnnImputer -0.024059  59520.557800
# 1132     KnnImputer -0.024079  59521.451371
#
# [1133 rows x 8 columns]

# %%
df["Scaler"]=df["Scaler"].fillna("None")
df["Scaler"]=df["Scaler"].apply(lambda x:"Normalizer" if x=="Nomalizer" else x)

# %%
df.sort_values("R2",ascending=False)
# Out:
#      Model  feature_selection  NOF        Scaler        Encoder  \
# 1110   SVR                UFS    5  Minmaxscaler  OnehotEncoder
# 904    SVR                UFS    5          None  OnehotEncoder
# 801    SVR                UFS    5  Minmaxscaler  OnehotEncoder
# 80     SVR                UFS    5    Normalizer   LabelEncoder
# 698    SVR                UFS    5    Normalizer  OnehotEncoder
# ...    ...                ...  ...           ...            ...
# 715    SVR                UFS   90    Normalizer  OnehotEncoder
# 713    SVR                UFS   80    Normalizer  OnehotEncoder
# 714    SVR                UFS   85    Normalizer  OnehotEncoder
# 79     SVR  VarianceThreshold  495    Normalizer   LabelEncoder
# 697    SVR  VarianceThreshold  495    Normalizer  OnehotEncoder
#
#             Imputer        R2           MAE
# 1110     KnnImputer -0.021714  59433.918503
# 904      KnnImputer -0.022123  59421.472437
# 801   SimpleImputer -0.022123  59421.472437
# 80    SimpleImputer -0.022325  59422.837119
# 698   SimpleImputer -0.022352  59423.902313
# ...             ...       ...           ...
# 715   SimpleImputer -0.024844  59562.252580
# 713   SimpleImputer -0.024844  59562.373275
# 714   SimpleImputer -0.024846  59562.367426
# 79    SimpleImputer -0.024849  59561.835119
# 697   SimpleImputer -0.024849  59561.835167
#
# [1133 rows x 8 columns]

# %% [markdown]
# # Distribution of R2 Score

# %%
sns.histplot(data=df,x="R2")
# Out:
# <Axes: xlabel='R2', ylabel='Count'>

# %% [markdown]
# # R2 score depend on UFS

# %%
sns.scatterplot(data=df.loc[(df["feature_selection"]=="UFS")],x="NOF",y="R2",hue="Scaler")
plt.xlabel("Number of feature")
# Out:
# Text(0.5, 0, 'Number of feature')

# %%
sns.boxplot(data=df.loc[(df["feature_selection"]=="UFS")],x="NOF",y="R2")
# Out:
# <Axes: xlabel='NOF', ylabel='R2'>

# %%
def find(nof,feature):
    maxr2_for_each_NOF=df.loc[(df["feature_selection"]==feature)].loc[(df["NOF"]==nof)]
    maxr2_for_each_NOF=maxr2_for_each_NOF.sort_values("R2",ascending=False).head(1)
    return maxr2_for_each_NOF

# %%
maxr2_for_each_NOF=find(5,"UFS")
for i in range(6,121):
    maxr2_for_each_NOF=pd.concat([maxr2_for_each_NOF,find(i,"UFS")])
maxr2_for_each_NOF
# Out:
#      Model feature_selection  NOF        Scaler        Encoder        Imputer  \
# 1110   SVR               UFS    5  Minmaxscaler  OnehotEncoder     KnnImputer
# 81     SVR               UFS   10    Normalizer   LabelEncoder  SimpleImputer
# 700    SVR               UFS   15    Normalizer  OnehotEncoder  SimpleImputer
# 1010   SVR               UFS   20    Normalizer  OnehotEncoder     KnnImputer
# 1011   SVR               UFS   25    Normalizer  OnehotEncoder     KnnImputer
# 1012   SVR               UFS   30    Normalizer  OnehotEncoder     KnnImputer
# 1013   SVR               UFS   35    Normalizer  OnehotEncoder     KnnImputer
# 1014   SVR               UFS   40    Normalizer  OnehotEncoder     KnnImputer
# 1015   SVR               UFS   45    Normalizer  OnehotEncoder     KnnImputer
# 1016   SVR               UFS   50    Normalizer  OnehotEncoder     KnnImputer
# 1017   SVR               UFS   55    Normalizer  OnehotEncoder     KnnImputer
# 1121   SVR               UFS   60  Minmaxscaler  OnehotEncoder     KnnImputer
# 1019   SVR               UFS   65    Normalizer  OnehotEncoder     KnnImputer
# 1123   SVR               UFS   70  Minmaxscaler  OnehotEncoder     KnnImputer
# 1124   SVR               UFS   75  Minmaxscaler  OnehotEncoder     KnnImputer
# 1125   SVR               UFS   80  Minmaxscaler  OnehotEncoder     KnnImputer
# 1126   SVR               UFS   85  Minmaxscaler  OnehotEncoder     KnnImputer
# 1127   SVR               UFS   90  Minmaxscaler  OnehotEncoder     KnnImputer
# 1128   SVR               UFS   95  Minmaxscaler  OnehotEncoder     KnnImputer
# 1129   SVR               UFS  100  Minmaxscaler  OnehotEncoder     KnnImputer
# 1130   SVR               UFS  105  Minmaxscaler  OnehotEncoder     KnnImputer
# 1131   SVR               UFS  110  Minmaxscaler  OnehotEncoder     KnnImputer
# 411    SVR               UFS  115    Normalizer   LabelEncoder     KnnImputer
#
#             R2           MAE
# 1110 -0.021714  59433.918503
# 81   -0.022389  59425.538588
# 700  -0.022412  59426.242376
# 1010 -0.023092  59470.471258
# 1011 -0.023185  59477.348703
# 1012 -0.023385  59487.559690
# 1013 -0.023279  59484.633227
# 1014 -0.023457  59490.040084
# 1015 -0.023586  59494.626071
# 1016 -0.023612  59495.957496
# 1017 -0.023679  59499.851453
# 1121 -0.023741  59502.335770
# 1019 -0.023808  59506.299440
# 1123 -0.023803  59506.799183
# 1124 -0.023829  59508.855734
# 1125 -0.023871  59510.826820
# 1126 -0.023903  59512.424966
# 1127 -0.023965  59515.739777
# 1128 -0.023994  59517.010509
# 1129 -0.024017  59518.243655
# 1130 -0.024033  59519.346637
# 1131 -0.024059  59520.557800
# 411  -0.024068  59528.144636

# %% [markdown]
# # Max R2 for each NOF

# %%
sns.lineplot(data=maxr2_for_each_NOF,x="NOF",y="R2",color="green")
# Out:
# <Axes: xlabel='NOF', ylabel='R2'>

# %%
maxr2_for_each_thresh=find(100,"VarianceThreshold")
for i in range(101,501):
    maxr2_for_each_thresh=pd.concat([maxr2_for_each_thresh,find(i,"VarianceThreshold")])
maxr2_for_each_thresh
# Out:
#     Model  feature_selection  NOF        Scaler       Encoder     Imputer  \
# 309   SVR  VarianceThreshold  100    Normalizer  LabelEncoder  KnnImputer
# 310   SVR  VarianceThreshold  105    Normalizer  LabelEncoder  KnnImputer
# 311   SVR  VarianceThreshold  110    Normalizer  LabelEncoder  KnnImputer
# 312   SVR  VarianceThreshold  115    Normalizer  LabelEncoder  KnnImputer
# 313   SVR  VarianceThreshold  120    Normalizer  LabelEncoder  KnnImputer
# ..    ...                ...  ...           ...           ...         ...
# 487   SVR  VarianceThreshold  475  Minmaxscaler  LabelEncoder  KnnImputer
# 488   SVR  VarianceThreshold  480  Minmaxscaler  LabelEncoder  KnnImputer
# 489   SVR  VarianceThreshold  485  Minmaxscaler  LabelEncoder  KnnImputer
# 490   SVR  VarianceThreshold  490  Minmaxscaler  LabelEncoder  KnnImputer
# 491   SVR  VarianceThreshold  495  Minmaxscaler  LabelEncoder  KnnImputer
#
#            R2           MAE
# 309 -0.024004  59525.180698
# 310 -0.023993  59524.604244
# 311 -0.023993  59524.604244
# 312 -0.023988  59524.387980
# 313 -0.023988  59524.387980
# ..        ...           ...
# 487 -0.024038  59525.058910
# 488 -0.024038  59525.058910
# 489 -0.024038  59525.058910
# 490 -0.024038  59525.058910
# 491 -0.024038  59525.058910
#
# [80 rows x 8 columns]

# %%
sns.lineplot(data=maxr2_for_each_thresh,x=df["NOF"]/100000,y="R2",color="green")
plt.xlabel("Threshold")
# Out:
# Text(0.5, 0, 'Threshold')

# %% [markdown]
# # R2 score depend on Variance Threshold

# %%
sns.scatterplot(data=df.loc[(df["feature_selection"]=="VarianceThreshold")],x=df["NOF"]/100000,y="R2",hue="Scaler")
plt.xlabel("Threshold")
# Out:
# Text(0.5, 0, 'Threshold')

# %% [markdown]
# # R2 depend on Scaler

# %%
sns.boxplot(data=df, x="Scaler",y="R2")
# Out:
# <Axes: xlabel='Scaler', ylabel='R2'>

# %% [markdown]
# # R2 depend on Imputer

# %%
sns.boxplot(data=df,x="Imputer",y="R2")
# Out:
# <Axes: xlabel='Imputer', ylabel='R2'>

# %%
sns.boxplot(data=df,x="Encoder",y="R2")
# Out:
# <Axes: xlabel='Encoder', ylabel='R2'>
