# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Model_Statistic.csv")
df
# Out:
#               Model  feature_selection  NOF      Scaler       Encoder  \
# 0     Decision_Tree  VarianceThreshold  100  Normalizer  LabelEncoder
# 1     Decision_Tree  VarianceThreshold  101  Normalizer  LabelEncoder
# 2     Decision_Tree  VarianceThreshold  102  Normalizer  LabelEncoder
# 3     Decision_Tree  VarianceThreshold  103  Normalizer  LabelEncoder
# 4     Decision_Tree  VarianceThreshold  104  Normalizer  LabelEncoder
# ...             ...                ...  ...         ...           ...
# 6175  Decision_Tree                UFS  115         NaN  LabelEncoder
# 6176  Decision_Tree                UFS  116         NaN  LabelEncoder
# 6177  Decision_Tree                UFS  117         NaN  LabelEncoder
# 6178  Decision_Tree                UFS  118         NaN  LabelEncoder
# 6179  Decision_Tree                UFS  119         NaN  LabelEncoder
#
#             Imputer        R2           MAE
# 0     SimpleImputer  0.533813  37391.976027
# 1     SimpleImputer  0.507139  37349.883562
# 2     SimpleImputer  0.405510  39699.544521
# 3     SimpleImputer  0.439501  38094.345890
# 4     SimpleImputer  0.447531  38271.934932
# ...             ...       ...           ...
# 6175  Simpleimputer  0.772012  27083.184932
# 6176  Simpleimputer  0.773417  26973.082192
# 6177  Simpleimputer  0.742740  28775.780822
# 6178  Simpleimputer  0.772986  26834.126712
# 6179  Simpleimputer  0.771365  27315.732877
#
# [6180 rows x 8 columns]

# %%
df["Scaler"]=df["Scaler"].fillna("None")
df["Imputer"]=df["Imputer"].apply(lambda x:"SimpleImputer" if x=="Simpleimputer" else x)

# %%
df.sort_values("R2",ascending=False)
# Out:
#               Model  feature_selection  NOF      Scaler       Encoder  \
# 3073  Decision_Tree                UFS  103        None  OnehotEncode
# 2984  Decision_Tree                UFS   14        None  OnehotEncode
# 3081  Decision_Tree                UFS  111        None  OnehotEncode
# 6075  Decision_Tree                UFS   15        None  LabelEncoder
# 6080  Decision_Tree                UFS   20        None  LabelEncoder
# ...             ...                ...  ...         ...           ...
# 1938  Decision_Tree  VarianceThreshold  493  Normalizer  LabelEncoder
# 1943  Decision_Tree  VarianceThreshold  498  Normalizer  LabelEncoder
# 1936  Decision_Tree  VarianceThreshold  491  Normalizer  LabelEncoder
# 1923  Decision_Tree  VarianceThreshold  478  Normalizer  LabelEncoder
# 1926  Decision_Tree  VarianceThreshold  481  Normalizer  LabelEncoder
#
#             Imputer        R2           MAE
# 3073  SimpleImputer  0.839077  24458.708904
# 2984  SimpleImputer  0.835797  24150.381849
# 3081  SimpleImputer  0.833782  24933.236301
# 6075  SimpleImputer  0.832067  23509.135274
# 6080  SimpleImputer  0.830804  23953.852740
# ...             ...       ...           ...
# 1938     Knnimputer -0.050086  58405.109589
# 1943     Knnimputer -0.050624  58726.623288
# 1936     Knnimputer -0.051035  58400.945205
# 1923     Knnimputer -0.061807  59131.599315
# 1926     Knnimputer -0.069781  59465.945205
#
# [6180 rows x 8 columns]

# %% [markdown]
# # Distribution of R2 Score

# %%
sns.histplot(data=df,x="R2")
# Out:
# <Axes: xlabel='R2', ylabel='Count'>

# %% [markdown]
# # R2 score depend on UFS

# %%
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(20,5),sharey=True,sharex=True)
sns.scatterplot(data=df.loc[(df["feature_selection"]=="UFS") & (df["Scaler"]=="None")  ],x="NOF",y="R2",ax=ax[0])
sns.scatterplot(data=df.loc[(df["feature_selection"]=="UFS") & (df["Scaler"]=="Normalizer")  ],x="NOF",y="R2",ax=ax[1],)
sns.scatterplot(data=df.loc[(df["feature_selection"]=="UFS") & (df["Scaler"]=="Minmaxscaler")],x="NOF",y="R2",ax=ax[2])
ax[0].title.set_text('None-Scaler')
ax[1].title.set_text('Normalizer')
ax[2].title.set_text('Minmaxscaler')

# %%
def find(nof,feature):
    maxr2_for_each_NOF=df.loc[(df["feature_selection"]==feature)].loc[(df["NOF"]==nof)]
    maxr2_for_each_NOF=maxr2_for_each_NOF.sort_values("R2",ascending=False).head(1)
    return maxr2_for_each_NOF

# %%
maxr2_for_each_NOF=find(5,"UFS")
for i in range(6,121):
    maxr2_for_each_NOF=pd.concat([maxr2_for_each_NOF,find(i,"UFS")])
maxr2_for_each_NOF
# Out:
#               Model feature_selection  NOF        Scaler       Encoder  \
# 6065  Decision_Tree               UFS    5          None  LabelEncoder
# 6066  Decision_Tree               UFS    6          None  LabelEncoder
# 6067  Decision_Tree               UFS    7          None  LabelEncoder
# 2978  Decision_Tree               UFS    8          None  OnehotEncode
# 6069  Decision_Tree               UFS    9          None  LabelEncoder
# ...             ...               ...  ...           ...           ...
# 2055  Decision_Tree               UFS  115    Normalizer  LabelEncoder
# 3086  Decision_Tree               UFS  116          None  OnehotEncode
# 3087  Decision_Tree               UFS  117          None  OnehotEncode
# 2573  Decision_Tree               UFS  118  Minmaxscaler  LabelEncoder
# 2059  Decision_Tree               UFS  119    Normalizer  LabelEncoder
#
#             Imputer        R2           MAE
# 6065  SimpleImputer  0.798793  25203.033105
# 6066  SimpleImputer  0.790396  26063.083333
# 6067  SimpleImputer  0.805504  24612.217466
# 2978  SimpleImputer  0.790982  25570.106164
# 6069  SimpleImputer  0.778898  25749.712329
# ...             ...       ...           ...
# 2055     Knnimputer  0.772730  27386.366438
# 3086  SimpleImputer  0.792886  26610.359589
# 3087  SimpleImputer  0.775756  26987.660959
# 2573     Knnimputer  0.789559  26011.222603
# 2059     Knnimputer  0.777582  26206.092466
#
# [115 rows x 8 columns]

# %% [markdown]
# # Max R2 for each NOF

# %%
sns.lineplot(data=maxr2_for_each_NOF,x="NOF",y="R2",color="green")
# Out:
# <Axes: xlabel='NOF', ylabel='R2'>

# %%
maxr2_for_each_thresh=find(100,"VarianceThreshold")
for i in range(101,501):
    maxr2_for_each_thresh=pd.concat([maxr2_for_each_thresh,find(i,"VarianceThreshold")])
maxr2_for_each_thresh
# Out:
#               Model  feature_selection  NOF        Scaler       Encoder  \
# 5665  Decision_Tree  VarianceThreshold  100          None  LabelEncoder
# 1546  Decision_Tree  VarianceThreshold  101    Normalizer  LabelEncoder
# 2062  Decision_Tree  VarianceThreshold  102  Minmaxscaler  LabelEncoder
# 2578  Decision_Tree  VarianceThreshold  103          None  OnehotEncode
# 5669  Decision_Tree  VarianceThreshold  104          None  LabelEncoder
# ...             ...                ...  ...           ...           ...
# 2455  Decision_Tree  VarianceThreshold  495  Minmaxscaler  LabelEncoder
# 2456  Decision_Tree  VarianceThreshold  496  Minmaxscaler  LabelEncoder
# 6062  Decision_Tree  VarianceThreshold  497          None  LabelEncoder
# 6063  Decision_Tree  VarianceThreshold  498          None  LabelEncoder
# 2459  Decision_Tree  VarianceThreshold  499  Minmaxscaler  LabelEncoder
#
#             Imputer        R2           MAE
# 5665  SimpleImputer  0.786976  27364.948630
# 1546     Knnimputer  0.791506  27122.647260
# 2062     Knnimputer  0.792857  25925.986301
# 2578  SimpleImputer  0.786644  27298.342466
# 5669  SimpleImputer  0.788253  26598.034247
# ...             ...       ...           ...
# 2455     Knnimputer  0.799709  27086.609589
# 2456     Knnimputer  0.793548  26882.195205
# 6062  SimpleImputer  0.786409  27167.428082
# 6063  SimpleImputer  0.770269  27578.842466
# 2459     Knnimputer  0.797679  26978.650685
#
# [400 rows x 8 columns]

# %%
sns.lineplot(data=maxr2_for_each_thresh,x=df["NOF"]/100000,y="R2",color="green")
plt.xlabel("Threshold")
# Out:
# Text(0.5, 0, 'Threshold')

# %% [markdown]
# # R2 score depend on Variance Threshold

# %%
sns.scatterplot(data=df.loc[(df["feature_selection"]=="VarianceThreshold")],x=df["NOF"]/100000,y="R2",hue="Scaler")
plt.xlabel("Threshold")
# Out:
# Text(0.5, 0, 'Threshold')

# %% [markdown]
# # R2 depend on Scaler

# %%
sns.boxplot(data=df, x="Scaler",y="R2")
# Out:
# <Axes: xlabel='Scaler', ylabel='R2'>

# %% [markdown]
# # R2 depend on Imputer

# %%
sns.boxplot(data=df,x="Imputer",y="R2")
# Out:
# <Axes: xlabel='Imputer', ylabel='R2'>

# %%
sns.boxplot(data=df,x="Encoder",y="R2")
# Out:
# <Axes: xlabel='Encoder', ylabel='R2'>
