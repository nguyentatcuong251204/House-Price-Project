# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error,root_mean_squared_error,r2_score

# %%
df=pd.read_csv(r"C:\Users\NTCUONG\notebook\training_LR\training12.csv")
df.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.288964     0.288900  0.237060     0.751485     0.490417   0.871241
# 1    0.089223     0.343729  0.262077     0.610590     0.764289   0.820615
# 2    0.277911     0.287757  0.312420     0.717292     0.467697   0.830206
# 3    0.323125     0.252112  0.260167     0.716555     0.467473   0.792212
# 4    0.249337     0.320285  0.360368     0.735365     0.415464   0.737297
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_WD  \
# 0      0.865572    0.127085    0.386851         0.0  ...     0.878061
# 1      0.815275    0.000000    0.514486         0.0  ...     0.842986
# 2      0.825241    0.101427    0.257144         0.0  ...     0.847863
# 3      0.810866    0.000000    0.113340         0.0  ...     0.840844
# 4      0.732499    0.197518    0.312378         0.0  ...     0.764231
#
#    SaleType_nan  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# 0             0               0.000000                    0.0
# 1             0               0.000000                    0.0
# 2             0               0.000000                    0.0
# 3             0               0.846186                    0.0
# 4             0               0.000000                    0.0
#
#    SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# 0                   0.0                   0.0              0.878061
# 1                   0.0                   0.0              0.842986
# 2                   0.0                   0.0              0.847863
# 3                   0.0                   0.0              0.000000
# 4                   0.0                   0.0              0.764231
#
#    SaleCondition_Partial  SaleCondition_nan  SalePrice
# 0                    0.0                  0     208500
# 1                    0.0                  0     181500
# 2                    0.0                  0     223500
# 3                    0.0                  0     140000
# 4                    0.0                  0     250000
#
# [5 rows x 305 columns]

# %%
corr=df.corr()

# %%
df.corr().sort_values("SalePrice",ascending=False).head(10)
# Out:
#                   MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# SalePrice          -0.142333     0.153551  0.334565     0.524853    -0.315803
# GrLivArea           0.120719     0.127222  0.008331     0.458779    -0.189161
# BsmtQual_Ex        -0.067336     0.110156  0.067300     0.348260    -0.213320
# TotalBsmtSF        -0.249588     0.188220  0.075357     0.407939    -0.225604
# GarageCars         -0.018763     0.150428  0.031077     0.494672    -0.234319
# OverallQual         0.168467     0.066253 -0.315555     1.000000     0.013580
# GarageArea         -0.093239     0.183610  0.084616     0.432730    -0.215405
# KitchenQual_Ex     -0.045219     0.075053  0.082089     0.310253    -0.121018
# 1stFlrSF           -0.239974     0.213064  0.017884     0.329802    -0.200665
# Foundation_PConc    0.095374     0.006098 -0.093198     0.553635    -0.264221
#
#                   YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# SalePrice         -0.472650     -0.499125    0.430345    0.332447   -0.033716
# GrLivArea         -0.218697     -0.219837    0.314464    0.031921   -0.061258
# BsmtQual_Ex       -0.159737     -0.176944    0.292843    0.219931   -0.043845
# TotalBsmtSF       -0.121166     -0.151733    0.281911    0.423329    0.085864
# GarageCars        -0.088925     -0.128104    0.308173    0.161393   -0.066607
# OverallQual        0.245853      0.217332    0.300476    0.115412   -0.102320
# GarageArea        -0.131911     -0.167525    0.309273    0.214881   -0.039942
# KitchenQual_Ex    -0.163811     -0.169290    0.214144    0.184403   -0.036469
# 1stFlrSF          -0.126223     -0.145328    0.251188    0.333430    0.065461
# Foundation_PConc   0.063893      0.026830    0.159577    0.056796   -0.147740
#
#                   ...  SaleType_WD  SaleType_nan  SaleCondition_Abnorml  \
# SalePrice         ...    -0.354417           NaN              -0.131030
# GrLivArea         ...    -0.151926           NaN              -0.057856
# BsmtQual_Ex       ...    -0.294995           NaN              -0.055523
# TotalBsmtSF       ...    -0.222430           NaN              -0.033628
# GarageCars        ...    -0.213203           NaN              -0.114808
# OverallQual       ...    -0.132284           NaN              -0.088225
# GarageArea        ...    -0.235569           NaN              -0.102522
# KitchenQual_Ex    ...    -0.210962           NaN               0.004694
# 1stFlrSF          ...    -0.210962           NaN              -0.033945
# Foundation_PConc  ...    -0.176319           NaN              -0.095768
#
#                   SaleCondition_AdjLand  SaleCondition_Alloca  \
# SalePrice                     -0.050800             -0.019783
# GrLivArea                     -0.043154              0.007535
# BsmtQual_Ex                   -0.015651             -0.027086
# TotalBsmtSF                   -0.063965             -0.074703
# GarageCars                    -0.109711              0.015857
# OverallQual                   -0.040849             -0.075064
# GarageArea                    -0.106532             -0.014841
# KitchenQual_Ex                -0.014103             -0.024406
# 1stFlrSF                      -0.040522              0.046827
# Foundation_PConc               0.007612             -0.043421
#
#                   SaleCondition_Family  SaleCondition_Normal  \
# SalePrice                    -0.048756             -0.249486
# GrLivArea                    -0.002907             -0.103951
# BsmtQual_Ex                  -0.035153             -0.231383
# TotalBsmtSF                   0.025350             -0.163098
# GarageCars                   -0.012673             -0.130096
# OverallQual                  -0.019867             -0.064936
# GarageArea                   -0.017159             -0.141364
# KitchenQual_Ex               -0.031675             -0.205273
# 1stFlrSF                      0.030706             -0.160864
# Foundation_PConc             -0.035719             -0.139283
#
#                   SaleCondition_Partial  SaleCondition_nan  SalePrice
# SalePrice                      0.333237                NaN   1.000000
# GrLivArea                      0.118027                NaN   0.607572
# BsmtQual_Ex                    0.342712                NaN   0.530566
# TotalBsmtSF                    0.229862                NaN   0.526490
# GarageCars                     0.257483                NaN   0.524947
# OverallQual                    0.266964                NaN   0.524853
# GarageArea                     0.262419                NaN   0.524351
# KitchenQual_Ex                 0.250091                NaN   0.481160
# 1stFlrSF                       0.182668                NaN   0.467500
# Foundation_PConc               0.306872                NaN   0.443080
#
# [10 rows x 305 columns]

# %%
def create_df(col_list):
    df_fs=df["SalePrice"]
    for col in col_list:
        df_fs=pd.concat([df[col],df_fs],axis=1)
    return df_fs

# %%
model=SVR()

# %%
def eval(df_fs):
    X_train,X_test,y_train,y_test=train_test_split(df_fs.iloc[:,:-1],df_fs.iloc[:,-1],test_size=0.2,random_state=42)
    model.fit(X_train,y_train)
    y_pre=model.predict(X_test)
    k.append(i)
    mae.append(mean_absolute_error(y_test,y_pre))
    rmse.append(root_mean_squared_error(y_test,y_pre))
    r2.append(r2_score(y_test,y_pre))

# %% [markdown]
# ### FEATURE SELECTION DEPEND ON CORRELATION MATRIX

# %% [markdown]
# plt.figure(figsize=(12,10))
# sns.heatmap(df.corr(),cmap='coolwarm')

# %%
c=corr.sort_values("SalePrice",ascending=False).head(10).index
c
# Out:
# Index(['SalePrice', 'GrLivArea', 'BsmtQual_Ex', 'TotalBsmtSF', 'GarageCars',
#        'OverallQual', 'GarageArea', 'KitchenQual_Ex', '1stFlrSF',
#        'Foundation_PConc'],
#       dtype='object')

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(10,120,5):
    c=corr.sort_values("SalePrice",ascending=False).iloc[1:i,:].index
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic
# Out:
#       K           MAE          RMSE        r2
# 0    10  59453.205835  88604.687628 -0.023528
# 1    15  59444.214406  88585.666978 -0.023088
# 2    20  59474.197324  88601.620501 -0.023457
# 3    25  59480.723522  88605.767845 -0.023553
# 4    30  59486.324286  88609.019745 -0.023628
# 5    35  59491.022622  88612.346587 -0.023705
# 6    40  59498.210088  88618.984803 -0.023858
# 7    45  59500.575882  88621.962025 -0.023927
# 8    50  59506.257621  88625.374043 -0.024006
# 9    55  59509.384192  88627.376833 -0.024052
# 10   60  59511.353310  88628.483232 -0.024077
# 11   65  59513.984385  88629.887336 -0.024110
# 12   70  59515.428007  88630.801536 -0.024131
# 13   75  59516.628357  88631.594889 -0.024149
# 14   80  59517.008492  88631.696257 -0.024152
# 15   85  59518.109779  88632.405635 -0.024168
# 16   90  59518.108780  88632.331023 -0.024166
# 17   95  59518.742041  88632.740661 -0.024176
# 18  100  59520.743578  88633.978618 -0.024204
# 19  105  59521.088318  88634.147827 -0.024208
# 20  110  59521.217909  88634.228368 -0.024210
# 21  115  59521.921033  88634.730662 -0.024222

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#       K           MAE          RMSE        r2
# 1    15  59444.214406  88585.666978 -0.023088
# 0    10  59453.205835  88604.687628 -0.023528
# 2    20  59474.197324  88601.620501 -0.023457
# 3    25  59480.723522  88605.767845 -0.023553
# 4    30  59486.324286  88609.019745 -0.023628
# 5    35  59491.022622  88612.346587 -0.023705
# 6    40  59498.210088  88618.984803 -0.023858
# 7    45  59500.575882  88621.962025 -0.023927
# 8    50  59506.257621  88625.374043 -0.024006
# 9    55  59509.384192  88627.376833 -0.024052
# 10   60  59511.353310  88628.483232 -0.024077
# 11   65  59513.984385  88629.887336 -0.024110
# 12   70  59515.428007  88630.801536 -0.024131
# 13   75  59516.628357  88631.594889 -0.024149
# 14   80  59517.008492  88631.696257 -0.024152
# 16   90  59518.108780  88632.331023 -0.024166
# 15   85  59518.109779  88632.405635 -0.024168
# 17   95  59518.742041  88632.740661 -0.024176
# 18  100  59520.743578  88633.978618 -0.024204
# 19  105  59521.088318  88634.147827 -0.024208
# 20  110  59521.217909  88634.228368 -0.024210
# 21  115  59521.921033  88634.730662 -0.024222

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### FEATURE SELECTION BY REMOVE FEATURE WITH LOW VARIENCE

# %% [markdown]
# ### 1.CALCULATE VARIENCE FOR EACH FEATURE

# %%
varr=np.var(df)
varr
# Out:
# D:\miniconda\lib\site-packages\numpy\core\fromnumeric.py:3785: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# MSSubClass               4.528134e-02
# LotFrontage              7.087096e-03
# LotArea                  1.397675e-02
# OverallQual              1.971269e-02
# OverallCond              1.660969e-02
#                              ...
# SaleCondition_Family     1.050945e-02
# SaleCondition_Normal     1.118082e-01
# SaleCondition_Partial    5.743050e-02
# SaleCondition_nan        0.000000e+00
# SalePrice                6.306789e+09
# Length: 305, dtype: float64

# %%
varr.loc[varr > 0.1].index
# Out:
# Index(['MSZoning_RL', 'MSZoning_RM', 'LotShape_IR1', 'LotShape_Reg',
#        'LotConfig_Corner', 'LotConfig_Inside', 'Neighborhood_NAmes',
#        'BldgType_1Fam', 'HouseStyle_1Story', 'HouseStyle_2Story',
#        'RoofStyle_Gable', 'RoofStyle_Hip', 'Exterior1st_MetalSd',
#        'Exterior1st_VinylSd', 'Exterior2nd_MetalSd', 'Exterior2nd_VinylSd',
#        'ExterQual_Gd', 'ExterQual_TA', 'Foundation_CBlock', 'Foundation_PConc',
#        'BsmtQual_Gd', 'BsmtQual_TA', 'BsmtExposure_No', 'BsmtFinType1_GLQ',
#        'BsmtFinType1_Unf', 'HeatingQC_Ex', 'HeatingQC_Gd', 'HeatingQC_TA',
#        'KitchenQual_Gd', 'KitchenQual_TA', 'GarageType_Attchd',
#        'GarageType_Detchd', 'GarageFinish_Fin', 'GarageFinish_RFn',
#        'GarageFinish_Unf', 'SaleCondition_Normal', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ### 2.USING VarianceThreshold FROM SKLEARN

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
varr_thresh=VarianceThreshold(threshold=0.1)
varr_thresh.fit_transform(df)
selected_columns = df.columns[varr_thresh.get_support()]
selected_columns
# Out:
# Index(['MSZoning_RL', 'MSZoning_RM', 'LotShape_IR1', 'LotShape_Reg',
#        'LotConfig_Corner', 'LotConfig_Inside', 'Neighborhood_NAmes',
#        'BldgType_1Fam', 'HouseStyle_1Story', 'HouseStyle_2Story',
#        'RoofStyle_Gable', 'RoofStyle_Hip', 'Exterior1st_MetalSd',
#        'Exterior1st_VinylSd', 'Exterior2nd_MetalSd', 'Exterior2nd_VinylSd',
#        'ExterQual_Gd', 'ExterQual_TA', 'Foundation_CBlock', 'Foundation_PConc',
#        'BsmtQual_Gd', 'BsmtQual_TA', 'BsmtExposure_No', 'BsmtFinType1_GLQ',
#        'BsmtFinType1_Unf', 'HeatingQC_Ex', 'HeatingQC_Gd', 'HeatingQC_TA',
#        'KitchenQual_Gd', 'KitchenQual_TA', 'GarageType_Attchd',
#        'GarageType_Detchd', 'GarageFinish_Fin', 'GarageFinish_RFn',
#        'GarageFinish_Unf', 'SaleCondition_Normal', 'SalePrice'],
#       dtype='object')

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(100,500,5):
    varr_thresh=VarianceThreshold(threshold=i/100000)
    varr_thresh.fit_transform(df.iloc[:,:-1])
    selected_columns = df.iloc[:,:-1].columns[varr_thresh.get_support()]
    df_fs=create_df(selected_columns)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic_var=pd.DataFrame(statistic_tup)
statistic_var
# Out:
#       K           MAE          RMSE        r2
# 0   100  59528.961007  88634.508781 -0.024217
# 1   105  59528.946382  88634.495580 -0.024216
# 2   110  59528.946382  88634.495580 -0.024216
# 3   115  59528.946382  88634.495580 -0.024216
# 4   120  59528.946382  88634.495580 -0.024216
# ..  ...           ...           ...       ...
# 75  475  59528.186101  88633.807081 -0.024200
# 76  480  59528.186101  88633.807081 -0.024200
# 77  485  59528.186101  88633.807081 -0.024200
# 78  490  59528.192145  88633.813521 -0.024201
# 79  495  59528.192145  88633.813521 -0.024201
#
# [80 rows x 4 columns]

# %%
statistic_var.sort_values("MAE",ascending=True)
# Out:
#       K           MAE          RMSE        r2
# 77  485  59528.186101  88633.807081 -0.024200
# 76  480  59528.186101  88633.807081 -0.024200
# 75  475  59528.186101  88633.807081 -0.024200
# 74  470  59528.186101  88633.807081 -0.024200
# 73  465  59528.186101  88633.807081 -0.024200
# ..  ...           ...           ...       ...
# 4   120  59528.946382  88634.495580 -0.024216
# 3   115  59528.946382  88634.495580 -0.024216
# 2   110  59528.946382  88634.495580 -0.024216
# 1   105  59528.946382  88634.495580 -0.024216
# 0   100  59528.961007  88634.508781 -0.024217
#
# [80 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x=statistic["K"]/1000,y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x=statistic["K"]/1000,y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\873788412.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\873788412.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### Univariate feature selection

# %% [markdown]
# ### Statistic function (r_regression, f_regression, mutual_info_regression)

# %% [markdown]
# ### 1. r_regression

# %% [markdown]
# ![image.png](attachment:f483b42b-de90-46a8-afcd-444eb978b015.png)

# %% [markdown]
# ### Using numpy

# %%
def similitary_score(x,y):
    x_avg=np.average(x)
    y_avg=np.average(y)
    up=np.sum((x-x_avg)*(y-y_avg))
    down=np.sqrt(np.sum((x-x_avg)**2)*np.sum((y-y_avg)**2))
    return up/down

# %%
print(similitary_score(df["OverallQual"],df["SalePrice"]))
# Out:
# 0.5248525198657469

# %%
top_feature=[]
for col in df.columns:
    score=similitary_score(df[col],df["SalePrice"])
    if col != "SalePrice" and score > 0.6:
        top_feature.append([col,score])
top_feature
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\2326211799.py:6: RuntimeWarning: invalid value encountered in scalar divide
#   return up/down
# [['GrLivArea', 0.6075721273224743]]

# %% [markdown]
# ### Using sklearn

# %%
from sklearn.feature_selection import r_regression
from sklearn.feature_selection import SelectKBest
# for i in range(5,21):
fs=SelectKBest(r_regression,k=6)
fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
# selected=df.columns[fs.get_support()]
fs.get_feature_names_out()
# Out:
# array(['OverallQual', 'TotalBsmtSF', 'GrLivArea', 'GarageCars',
#        'GarageArea', 'BsmtQual_Ex'], dtype=object)

# %%
k, mae, rmse, r2 = [], [], [], []

for i in range(5,120,5):
    fs=SelectKBest(r_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic.to_csv("r_regression_label_enc.csv")
statistic
# Out:
#       K           MAE          RMSE        r2
# 0     5  59497.118879  88610.244701 -0.023656
# 1    10  59458.790320  88608.723482 -0.023621
# 2    15  59450.979360  88590.009947 -0.023189
# 3    20  59474.237196  88601.271612 -0.023449
# 4    25  59473.861858  88605.322848 -0.023542
# 5    30  59486.871821  88609.587574 -0.023641
# 6    35  59492.123829  88615.105495 -0.023768
# 7    40  59499.011324  88619.619736 -0.023873
# 8    45  59504.008478  88624.083741 -0.023976
# 9    50  59508.090626  88626.570001 -0.024033
# 10   55  59509.479186  88627.340704 -0.024051
# 11   60  59511.388252  88628.414699 -0.024076
# 12   65  59514.080850  88629.943055 -0.024111
# 13   70  59515.403476  88630.762926 -0.024130
# 14   75  59516.628272  88631.556161 -0.024148
# 15   80  59517.685247  88632.146853 -0.024162
# 16   85  59518.123334  88632.410668 -0.024168
# 17   90  59518.149245  88632.357081 -0.024167
# 18   95  59518.762364  88632.742921 -0.024176
# 19  100  59520.777454  88634.001097 -0.024205
# 20  105  59521.109255  88634.159930 -0.024209
# 21  110  59521.210854  88634.219201 -0.024210
# 22  115  59521.307239  88634.276154 -0.024211

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#       K           MAE          RMSE        r2
# 2    15  59450.979360  88590.009947 -0.023189
# 1    10  59458.790320  88608.723482 -0.023621
# 4    25  59473.861858  88605.322848 -0.023542
# 3    20  59474.237196  88601.271612 -0.023449
# 5    30  59486.871821  88609.587574 -0.023641
# 6    35  59492.123829  88615.105495 -0.023768
# 0     5  59497.118879  88610.244701 -0.023656
# 7    40  59499.011324  88619.619736 -0.023873
# 8    45  59504.008478  88624.083741 -0.023976
# 9    50  59508.090626  88626.570001 -0.024033
# 10   55  59509.479186  88627.340704 -0.024051
# 11   60  59511.388252  88628.414699 -0.024076
# 12   65  59514.080850  88629.943055 -0.024111
# 13   70  59515.403476  88630.762926 -0.024130
# 14   75  59516.628272  88631.556161 -0.024148
# 15   80  59517.685247  88632.146853 -0.024162
# 16   85  59518.123334  88632.410668 -0.024168
# 17   90  59518.149245  88632.357081 -0.024167
# 18   95  59518.762364  88632.742921 -0.024176
# 19  100  59520.777454  88634.001097 -0.024205
# 20  105  59521.109255  88634.159930 -0.024209
# 21  110  59521.210854  88634.219201 -0.024210
# 22  115  59521.307239  88634.276154 -0.024211

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### 2.f_regression

# %% [markdown]
# ![image.png](attachment:95f14443-0240-442c-b294-562b150eb8bd.png)

# %% [markdown]
# ![image.png](attachment:a344f6dc-6cf9-490d-a595-9c80c9c1128a.png)

# %%
from sklearn.feature_selection import f_regression

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(5,120,5):
    fs=SelectKBest(f_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic.to_csv("f_regression_label_enc.csv")
statistic
# Out:
#       K           MAE          RMSE        r2
# 0     5  59381.187321  88496.400066 -0.021027
# 1    10  59420.012044  88538.938073 -0.022009
# 2    15  59444.478423  88555.265241 -0.022386
# 3    20  59436.356112  88566.430563 -0.022644
# 4    25  59437.761119  88562.999211 -0.022565
# 5    30  59453.335828  88576.170137 -0.022869
# 6    35  59463.281824  88585.589496 -0.023086
# 7    40  59472.194467  88591.899161 -0.023232
# 8    45  59480.191025  88597.660456 -0.023365
# 9    50  59484.630383  88600.632345 -0.023434
# 10   55  59488.382741  88604.609852 -0.023526
# 11   60  59492.831822  88607.967028 -0.023603
# 12   65  59495.266492  88609.383161 -0.023636
# 13   70  59498.844758  88611.545716 -0.023686
# 14   75  59501.288409  88614.671560 -0.023758
# 15   80  59504.674801  88617.115287 -0.023815
# 16   85  59506.618048  88618.631571 -0.023850
# 17   90  59507.011898  88619.029538 -0.023859
# 18   95  59509.422637  88620.823779 -0.023900
# 19  100  59511.273565  88621.831063 -0.023924
# 20  105  59512.636917  88622.427987 -0.023938
# 21  110  59513.627462  88623.203063 -0.023955
# 22  115  59514.430519  88623.834469 -0.023970

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#       K           MAE          RMSE        r2
# 0     5  59381.187321  88496.400066 -0.021027
# 1    10  59420.012044  88538.938073 -0.022009
# 3    20  59436.356112  88566.430563 -0.022644
# 4    25  59437.761119  88562.999211 -0.022565
# 2    15  59444.478423  88555.265241 -0.022386
# 5    30  59453.335828  88576.170137 -0.022869
# 6    35  59463.281824  88585.589496 -0.023086
# 7    40  59472.194467  88591.899161 -0.023232
# 8    45  59480.191025  88597.660456 -0.023365
# 9    50  59484.630383  88600.632345 -0.023434
# 10   55  59488.382741  88604.609852 -0.023526
# 11   60  59492.831822  88607.967028 -0.023603
# 12   65  59495.266492  88609.383161 -0.023636
# 13   70  59498.844758  88611.545716 -0.023686
# 14   75  59501.288409  88614.671560 -0.023758
# 15   80  59504.674801  88617.115287 -0.023815
# 16   85  59506.618048  88618.631571 -0.023850
# 17   90  59507.011898  88619.029538 -0.023859
# 18   95  59509.422637  88620.823779 -0.023900
# 19  100  59511.273565  88621.831063 -0.023924
# 20  105  59512.636917  88622.427987 -0.023938
# 21  110  59513.627462  88623.203063 -0.023955
# 22  115  59514.430519  88623.834469 -0.023970

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### 3.Mutual infomation

# %% [markdown]
# ### Fomula

# %% [markdown]
# ![image.png](attachment:283a97b8-8534-4c70-8086-d6b229834262.png)

# %% [markdown]
# ### Mesure dependency of 2 variable X,Y

# %% [markdown]
# ### KDE method (Estimate Probability Density Function)

# %% [markdown]
# ![image.png](attachment:d3173b36-c1e3-421a-a817-095dbfd9041c.png)

# %% [markdown]
# ![image.png](attachment:88044c6a-ccc1-4d54-bbb2-f410d59aa145.png)

# %% [markdown]
# ![image.png](attachment:5c8079a5-deea-43ef-85ff-0e46935b227e.png)

# %%
all_col=df.columns
all_col
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        ...
#        'SaleType_WD', 'SaleType_nan', 'SaleCondition_Abnorml',
#        'SaleCondition_AdjLand', 'SaleCondition_Alloca', 'SaleCondition_Family',
#        'SaleCondition_Normal', 'SaleCondition_Partial', 'SaleCondition_nan',
#        'SalePrice'],
#       dtype='object', length=305)

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(5,120,5):
    fs=SelectKBest(mutual_info_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic
# Out:
#       K           MAE          RMSE        r2
# 0     5  59433.918503  88526.152752 -0.021714
# 1    10  59482.610634  88573.337215 -0.022803
# 2    15  59468.436926  88578.905054 -0.022932
# 3    20  59472.803151  88588.828194 -0.023161
# 4    25  59481.397233  88594.043911 -0.023282
# 5    30  59491.338642  88602.149603 -0.023469
# 6    35  59492.065170  88600.547485 -0.023432
# 7    40  59491.021853  88603.214019 -0.023494
# 8    45  59495.115293  88609.219924 -0.023632
# 9    50  59495.848014  88609.233071 -0.023633
# 10   55  59499.881776  88612.095897 -0.023699
# 11   60  59502.335770  88613.921406 -0.023741
# 12   65  59506.701137  88617.052611 -0.023813
# 13   70  59506.799183  88616.627985 -0.023803
# 14   75  59508.855734  88617.730101 -0.023829
# 15   80  59510.826820  88619.539228 -0.023871
# 16   85  59512.424966  88620.924100 -0.023903
# 17   90  59515.739777  88623.623493 -0.023965
# 18   95  59517.010509  88624.887278 -0.023994
# 19  100  59518.243655  88625.857667 -0.024017
# 20  105  59519.346637  88626.558544 -0.024033
# 21  110  59520.557800  88627.704061 -0.024059
# 22  115  59521.451371  88628.540598 -0.024079

# %%
statistic.to_csv("mutual_infomation_label_enc.csv")

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#       K           MAE          RMSE        r2
# 0     5  59433.918503  88526.152752 -0.021714
# 2    15  59468.436926  88578.905054 -0.022932
# 3    20  59472.803151  88588.828194 -0.023161
# 4    25  59481.397233  88594.043911 -0.023282
# 1    10  59482.610634  88573.337215 -0.022803
# 7    40  59491.021853  88603.214019 -0.023494
# 5    30  59491.338642  88602.149603 -0.023469
# 6    35  59492.065170  88600.547485 -0.023432
# 8    45  59495.115293  88609.219924 -0.023632
# 9    50  59495.848014  88609.233071 -0.023633
# 10   55  59499.881776  88612.095897 -0.023699
# 11   60  59502.335770  88613.921406 -0.023741
# 12   65  59506.701137  88617.052611 -0.023813
# 13   70  59506.799183  88616.627985 -0.023803
# 14   75  59508.855734  88617.730101 -0.023829
# 15   80  59510.826820  88619.539228 -0.023871
# 16   85  59512.424966  88620.924100 -0.023903
# 17   90  59515.739777  88623.623493 -0.023965
# 18   95  59517.010509  88624.887278 -0.023994
# 19  100  59518.243655  88625.857667 -0.024017
# 20  105  59519.346637  88626.558544 -0.024033
# 21  110  59520.557800  88627.704061 -0.024059
# 22  115  59521.451371  88628.540598 -0.024079

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_16024\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### RFE (Recursive feature elimination)

# %% [markdown]
# df

# %% [markdown]
# from sklearn.feature_selection import RFE,RFECV
# rfe=RFE(estimator=model,n_features_to_select=5)
# rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
# rfe.get_feature_names_out()

# %% [markdown]
# k, mae, rmse, r2 = [], [], [], []
# for i in range(10,50):
#     rfe=RFE(estimator=model,n_features_to_select=i)
#     rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
#     c = df.iloc[:,:-1].columns[rfe.support_]
#     df_fs=create_df(c)
#     eval(df_fs)
# statistic_tup={
#     "K":k,
#     "MAE":mae,
#     "RMSE":rmse,
#     "r2":r2
# }
# statistic=pd.DataFrame(statistic_tup)
# statistic

# %% [markdown]
# statistic.to_csv("RFE.csv")

# %% [markdown]
# statistic=pd.read_csv("RFE.csv")

# %% [markdown]
# fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
# ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
# ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
# ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
# plt.show()

# %% [markdown]
# k, mae, rmse, r2 = [], [], [], []
# for i in range(10,15):
#     rfe=RFECV(estimator=model,min_features_to_select=i,cv=5)
#     rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
#     c = df.iloc[:,:-1].columns[rfe.support_]
#     df_fs=create_df(c)
#     eval(df_fs)
# statistic_tup={
#     "K":k,
#     "MAE":mae,
#     "RMSE":rmse,
#     "r2":r2
# }
# statistic=pd.DataFrame(statistic_tup)
# statistic

# %% [markdown]
# fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
# ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
# ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
# ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
# plt.show()

# %% [markdown]
# statistic.to_csv("RFECV.csv")

# %%
r=pd.read_csv("r_regression_label_enc.csv")
r=r.iloc[:,1:]
r
# Out:
#       K           MAE          RMSE        r2
# 0     5  59497.118879  88610.244701 -0.023656
# 1    10  59458.790320  88608.723482 -0.023621
# 2    15  59450.979360  88590.009947 -0.023189
# 3    20  59474.237196  88601.271612 -0.023449
# 4    25  59473.861858  88605.322848 -0.023542
# 5    30  59486.871821  88609.587574 -0.023641
# 6    35  59492.123829  88615.105495 -0.023768
# 7    40  59499.011324  88619.619736 -0.023873
# 8    45  59504.008478  88624.083741 -0.023976
# 9    50  59508.090626  88626.570001 -0.024033
# 10   55  59509.479186  88627.340704 -0.024051
# 11   60  59511.388252  88628.414699 -0.024076
# 12   65  59514.080850  88629.943055 -0.024111
# 13   70  59515.403476  88630.762926 -0.024130
# 14   75  59516.628272  88631.556161 -0.024148
# 15   80  59517.685247  88632.146853 -0.024162
# 16   85  59518.123334  88632.410668 -0.024168
# 17   90  59518.149245  88632.357081 -0.024167
# 18   95  59518.762364  88632.742921 -0.024176
# 19  100  59520.777454  88634.001097 -0.024205
# 20  105  59521.109255  88634.159930 -0.024209
# 21  110  59521.210854  88634.219201 -0.024210
# 22  115  59521.307239  88634.276154 -0.024211

# %%
f=pd.read_csv("f_regression_label_enc.csv")
f=f.iloc[:,1:]
f
# Out:
#       K           MAE          RMSE        r2
# 0     5  59381.187321  88496.400066 -0.021027
# 1    10  59420.012044  88538.938073 -0.022009
# 2    15  59444.478423  88555.265241 -0.022386
# 3    20  59436.356112  88566.430563 -0.022644
# 4    25  59437.761119  88562.999211 -0.022565
# 5    30  59453.335828  88576.170137 -0.022869
# 6    35  59463.281824  88585.589496 -0.023086
# 7    40  59472.194467  88591.899161 -0.023232
# 8    45  59480.191025  88597.660456 -0.023365
# 9    50  59484.630383  88600.632345 -0.023434
# 10   55  59488.382741  88604.609852 -0.023526
# 11   60  59492.831822  88607.967028 -0.023603
# 12   65  59495.266492  88609.383161 -0.023636
# 13   70  59498.844758  88611.545716 -0.023686
# 14   75  59501.288409  88614.671560 -0.023758
# 15   80  59504.674801  88617.115287 -0.023815
# 16   85  59506.618048  88618.631571 -0.023850
# 17   90  59507.011898  88619.029538 -0.023859
# 18   95  59509.422637  88620.823779 -0.023900
# 19  100  59511.273565  88621.831063 -0.023924
# 20  105  59512.636917  88622.427987 -0.023938
# 21  110  59513.627462  88623.203063 -0.023955
# 22  115  59514.430519  88623.834469 -0.023970

# %%
mutual=pd.read_csv("mutual_infomation_label_enc.csv")
mutual=mutual.iloc[:,1:]
mutual
# Out:
#       K           MAE          RMSE        r2
# 0     5  59433.918503  88526.152752 -0.021714
# 1    10  59482.610634  88573.337215 -0.022803
# 2    15  59468.436926  88578.905054 -0.022932
# 3    20  59472.803151  88588.828194 -0.023161
# 4    25  59481.397233  88594.043911 -0.023282
# 5    30  59491.338642  88602.149603 -0.023469
# 6    35  59492.065170  88600.547485 -0.023432
# 7    40  59491.021853  88603.214019 -0.023494
# 8    45  59495.115293  88609.219924 -0.023632
# 9    50  59495.848014  88609.233071 -0.023633
# 10   55  59499.881776  88612.095897 -0.023699
# 11   60  59502.335770  88613.921406 -0.023741
# 12   65  59506.701137  88617.052611 -0.023813
# 13   70  59506.799183  88616.627985 -0.023803
# 14   75  59508.855734  88617.730101 -0.023829
# 15   80  59510.826820  88619.539228 -0.023871
# 16   85  59512.424966  88620.924100 -0.023903
# 17   90  59515.739777  88623.623493 -0.023965
# 18   95  59517.010509  88624.887278 -0.023994
# 19  100  59518.243655  88625.857667 -0.024017
# 20  105  59519.346637  88626.558544 -0.024033
# 21  110  59520.557800  88627.704061 -0.024059
# 22  115  59521.451371  88628.540598 -0.024079

# %%
joint=pd.merge(r,f,how='inner',on="K")
joint
# Out:
#       K         MAE_x        RMSE_x      r2_x         MAE_y        RMSE_y  \
# 0     5  59497.118879  88610.244701 -0.023656  59381.187321  88496.400066
# 1    10  59458.790320  88608.723482 -0.023621  59420.012044  88538.938073
# 2    15  59450.979360  88590.009947 -0.023189  59444.478423  88555.265241
# 3    20  59474.237196  88601.271612 -0.023449  59436.356112  88566.430563
# 4    25  59473.861858  88605.322848 -0.023542  59437.761119  88562.999211
# 5    30  59486.871821  88609.587574 -0.023641  59453.335828  88576.170137
# 6    35  59492.123829  88615.105495 -0.023768  59463.281824  88585.589496
# 7    40  59499.011324  88619.619736 -0.023873  59472.194467  88591.899161
# 8    45  59504.008478  88624.083741 -0.023976  59480.191025  88597.660456
# 9    50  59508.090626  88626.570001 -0.024033  59484.630383  88600.632345
# 10   55  59509.479186  88627.340704 -0.024051  59488.382741  88604.609852
# 11   60  59511.388252  88628.414699 -0.024076  59492.831822  88607.967028
# 12   65  59514.080850  88629.943055 -0.024111  59495.266492  88609.383161
# 13   70  59515.403476  88630.762926 -0.024130  59498.844758  88611.545716
# 14   75  59516.628272  88631.556161 -0.024148  59501.288409  88614.671560
# 15   80  59517.685247  88632.146853 -0.024162  59504.674801  88617.115287
# 16   85  59518.123334  88632.410668 -0.024168  59506.618048  88618.631571
# 17   90  59518.149245  88632.357081 -0.024167  59507.011898  88619.029538
# 18   95  59518.762364  88632.742921 -0.024176  59509.422637  88620.823779
# 19  100  59520.777454  88634.001097 -0.024205  59511.273565  88621.831063
# 20  105  59521.109255  88634.159930 -0.024209  59512.636917  88622.427987
# 21  110  59521.210854  88634.219201 -0.024210  59513.627462  88623.203063
# 22  115  59521.307239  88634.276154 -0.024211  59514.430519  88623.834469
#
#         r2_y
# 0  -0.021027
# 1  -0.022009
# 2  -0.022386
# 3  -0.022644
# 4  -0.022565
# 5  -0.022869
# 6  -0.023086
# 7  -0.023232
# 8  -0.023365
# 9  -0.023434
# 10 -0.023526
# 11 -0.023603
# 12 -0.023636
# 13 -0.023686
# 14 -0.023758
# 15 -0.023815
# 16 -0.023850
# 17 -0.023859
# 18 -0.023900
# 19 -0.023924
# 20 -0.023938
# 21 -0.023955
# 22 -0.023970

# %%
joint=pd.merge(joint,mutual,on="K",how="inner")
joint
# Out:
#       K         MAE_x        RMSE_x      r2_x         MAE_y        RMSE_y  \
# 0     5  59497.118879  88610.244701 -0.023656  59381.187321  88496.400066
# 1    10  59458.790320  88608.723482 -0.023621  59420.012044  88538.938073
# 2    15  59450.979360  88590.009947 -0.023189  59444.478423  88555.265241
# 3    20  59474.237196  88601.271612 -0.023449  59436.356112  88566.430563
# 4    25  59473.861858  88605.322848 -0.023542  59437.761119  88562.999211
# 5    30  59486.871821  88609.587574 -0.023641  59453.335828  88576.170137
# 6    35  59492.123829  88615.105495 -0.023768  59463.281824  88585.589496
# 7    40  59499.011324  88619.619736 -0.023873  59472.194467  88591.899161
# 8    45  59504.008478  88624.083741 -0.023976  59480.191025  88597.660456
# 9    50  59508.090626  88626.570001 -0.024033  59484.630383  88600.632345
# 10   55  59509.479186  88627.340704 -0.024051  59488.382741  88604.609852
# 11   60  59511.388252  88628.414699 -0.024076  59492.831822  88607.967028
# 12   65  59514.080850  88629.943055 -0.024111  59495.266492  88609.383161
# 13   70  59515.403476  88630.762926 -0.024130  59498.844758  88611.545716
# 14   75  59516.628272  88631.556161 -0.024148  59501.288409  88614.671560
# 15   80  59517.685247  88632.146853 -0.024162  59504.674801  88617.115287
# 16   85  59518.123334  88632.410668 -0.024168  59506.618048  88618.631571
# 17   90  59518.149245  88632.357081 -0.024167  59507.011898  88619.029538
# 18   95  59518.762364  88632.742921 -0.024176  59509.422637  88620.823779
# 19  100  59520.777454  88634.001097 -0.024205  59511.273565  88621.831063
# 20  105  59521.109255  88634.159930 -0.024209  59512.636917  88622.427987
# 21  110  59521.210854  88634.219201 -0.024210  59513.627462  88623.203063
# 22  115  59521.307239  88634.276154 -0.024211  59514.430519  88623.834469
#
#         r2_y           MAE          RMSE        r2
# 0  -0.021027  59433.918503  88526.152752 -0.021714
# 1  -0.022009  59482.610634  88573.337215 -0.022803
# 2  -0.022386  59468.436926  88578.905054 -0.022932
# 3  -0.022644  59472.803151  88588.828194 -0.023161
# 4  -0.022565  59481.397233  88594.043911 -0.023282
# 5  -0.022869  59491.338642  88602.149603 -0.023469
# 6  -0.023086  59492.065170  88600.547485 -0.023432
# 7  -0.023232  59491.021853  88603.214019 -0.023494
# 8  -0.023365  59495.115293  88609.219924 -0.023632
# 9  -0.023434  59495.848014  88609.233071 -0.023633
# 10 -0.023526  59499.881776  88612.095897 -0.023699
# 11 -0.023603  59502.335770  88613.921406 -0.023741
# 12 -0.023636  59506.701137  88617.052611 -0.023813
# 13 -0.023686  59506.799183  88616.627985 -0.023803
# 14 -0.023758  59508.855734  88617.730101 -0.023829
# 15 -0.023815  59510.826820  88619.539228 -0.023871
# 16 -0.023850  59512.424966  88620.924100 -0.023903
# 17 -0.023859  59515.739777  88623.623493 -0.023965
# 18 -0.023900  59517.010509  88624.887278 -0.023994
# 19 -0.023924  59518.243655  88625.857667 -0.024017
# 20 -0.023938  59519.346637  88626.558544 -0.024033
# 21 -0.023955  59520.557800  88627.704061 -0.024059
# 22 -0.023970  59521.451371  88628.540598 -0.024079

# %%
columns=["Model", "feature_selection", "NOF", "Scaler", "Encoder" ,"Imputer", "R2", "MAE"]

# %%
df_result=pd.DataFrame(columns=columns)
df_result
# Out:
# Empty DataFrame
# Columns: [Model, feature_selection, NOF, Scaler, Encoder, Imputer, R2, MAE]
# Index: []

# %%
df_result["NOF"]=joint["K"]
df_result["R2"]=joint["r2"]
df_result["MAE"]=joint["MAE"]
df_result
# Out:
#    Model feature_selection  NOF Scaler Encoder Imputer        R2           MAE
# 0    NaN               NaN    5    NaN     NaN     NaN -0.021714  59433.918503
# 1    NaN               NaN   10    NaN     NaN     NaN -0.022803  59482.610634
# 2    NaN               NaN   15    NaN     NaN     NaN -0.022932  59468.436926
# 3    NaN               NaN   20    NaN     NaN     NaN -0.023161  59472.803151
# 4    NaN               NaN   25    NaN     NaN     NaN -0.023282  59481.397233
# 5    NaN               NaN   30    NaN     NaN     NaN -0.023469  59491.338642
# 6    NaN               NaN   35    NaN     NaN     NaN -0.023432  59492.065170
# 7    NaN               NaN   40    NaN     NaN     NaN -0.023494  59491.021853
# 8    NaN               NaN   45    NaN     NaN     NaN -0.023632  59495.115293
# 9    NaN               NaN   50    NaN     NaN     NaN -0.023633  59495.848014
# 10   NaN               NaN   55    NaN     NaN     NaN -0.023699  59499.881776
# 11   NaN               NaN   60    NaN     NaN     NaN -0.023741  59502.335770
# 12   NaN               NaN   65    NaN     NaN     NaN -0.023813  59506.701137
# 13   NaN               NaN   70    NaN     NaN     NaN -0.023803  59506.799183
# 14   NaN               NaN   75    NaN     NaN     NaN -0.023829  59508.855734
# 15   NaN               NaN   80    NaN     NaN     NaN -0.023871  59510.826820
# 16   NaN               NaN   85    NaN     NaN     NaN -0.023903  59512.424966
# 17   NaN               NaN   90    NaN     NaN     NaN -0.023965  59515.739777
# 18   NaN               NaN   95    NaN     NaN     NaN -0.023994  59517.010509
# 19   NaN               NaN  100    NaN     NaN     NaN -0.024017  59518.243655
# 20   NaN               NaN  105    NaN     NaN     NaN -0.024033  59519.346637
# 21   NaN               NaN  110    NaN     NaN     NaN -0.024059  59520.557800
# 22   NaN               NaN  115    NaN     NaN     NaN -0.024079  59521.451371

# %%
df_result["Model"]="SVR"
df_result["feature_selection"]="UFS"

# %%
joint
# Out:
#       K         MAE_x        RMSE_x      r2_x         MAE_y        RMSE_y  \
# 0     5  59497.118879  88610.244701 -0.023656  59381.187321  88496.400066
# 1    10  59458.790320  88608.723482 -0.023621  59420.012044  88538.938073
# 2    15  59450.979360  88590.009947 -0.023189  59444.478423  88555.265241
# 3    20  59474.237196  88601.271612 -0.023449  59436.356112  88566.430563
# 4    25  59473.861858  88605.322848 -0.023542  59437.761119  88562.999211
# 5    30  59486.871821  88609.587574 -0.023641  59453.335828  88576.170137
# 6    35  59492.123829  88615.105495 -0.023768  59463.281824  88585.589496
# 7    40  59499.011324  88619.619736 -0.023873  59472.194467  88591.899161
# 8    45  59504.008478  88624.083741 -0.023976  59480.191025  88597.660456
# 9    50  59508.090626  88626.570001 -0.024033  59484.630383  88600.632345
# 10   55  59509.479186  88627.340704 -0.024051  59488.382741  88604.609852
# 11   60  59511.388252  88628.414699 -0.024076  59492.831822  88607.967028
# 12   65  59514.080850  88629.943055 -0.024111  59495.266492  88609.383161
# 13   70  59515.403476  88630.762926 -0.024130  59498.844758  88611.545716
# 14   75  59516.628272  88631.556161 -0.024148  59501.288409  88614.671560
# 15   80  59517.685247  88632.146853 -0.024162  59504.674801  88617.115287
# 16   85  59518.123334  88632.410668 -0.024168  59506.618048  88618.631571
# 17   90  59518.149245  88632.357081 -0.024167  59507.011898  88619.029538
# 18   95  59518.762364  88632.742921 -0.024176  59509.422637  88620.823779
# 19  100  59520.777454  88634.001097 -0.024205  59511.273565  88621.831063
# 20  105  59521.109255  88634.159930 -0.024209  59512.636917  88622.427987
# 21  110  59521.210854  88634.219201 -0.024210  59513.627462  88623.203063
# 22  115  59521.307239  88634.276154 -0.024211  59514.430519  88623.834469
#
#         r2_y           MAE          RMSE        r2
# 0  -0.021027  59433.918503  88526.152752 -0.021714
# 1  -0.022009  59482.610634  88573.337215 -0.022803
# 2  -0.022386  59468.436926  88578.905054 -0.022932
# 3  -0.022644  59472.803151  88588.828194 -0.023161
# 4  -0.022565  59481.397233  88594.043911 -0.023282
# 5  -0.022869  59491.338642  88602.149603 -0.023469
# 6  -0.023086  59492.065170  88600.547485 -0.023432
# 7  -0.023232  59491.021853  88603.214019 -0.023494
# 8  -0.023365  59495.115293  88609.219924 -0.023632
# 9  -0.023434  59495.848014  88609.233071 -0.023633
# 10 -0.023526  59499.881776  88612.095897 -0.023699
# 11 -0.023603  59502.335770  88613.921406 -0.023741
# 12 -0.023636  59506.701137  88617.052611 -0.023813
# 13 -0.023686  59506.799183  88616.627985 -0.023803
# 14 -0.023758  59508.855734  88617.730101 -0.023829
# 15 -0.023815  59510.826820  88619.539228 -0.023871
# 16 -0.023850  59512.424966  88620.924100 -0.023903
# 17 -0.023859  59515.739777  88623.623493 -0.023965
# 18 -0.023900  59517.010509  88624.887278 -0.023994
# 19 -0.023924  59518.243655  88625.857667 -0.024017
# 20 -0.023938  59519.346637  88626.558544 -0.024033
# 21 -0.023955  59520.557800  88627.704061 -0.024059
# 22 -0.023970  59521.451371  88628.540598 -0.024079

# %%
df_var=pd.DataFrame(columns=columns)
df_var
# Out:
# Empty DataFrame
# Columns: [Model, feature_selection, NOF, Scaler, Encoder, Imputer, R2, MAE]
# Index: []

# %%
df_var["NOF"]=statistic_var["K"]
df_var["R2"]=statistic_var["r2"]
df_var["MAE"]=statistic_var["MAE"]
df_var["Model"]="SVR"
df_var["feature_selection"]="VarianceThreshold"
df_var
# Out:
#    Model  feature_selection  NOF Scaler Encoder Imputer        R2  \
# 0    SVR  VarianceThreshold  100    NaN     NaN     NaN -0.024217
# 1    SVR  VarianceThreshold  105    NaN     NaN     NaN -0.024216
# 2    SVR  VarianceThreshold  110    NaN     NaN     NaN -0.024216
# 3    SVR  VarianceThreshold  115    NaN     NaN     NaN -0.024216
# 4    SVR  VarianceThreshold  120    NaN     NaN     NaN -0.024216
# ..   ...                ...  ...    ...     ...     ...       ...
# 75   SVR  VarianceThreshold  475    NaN     NaN     NaN -0.024200
# 76   SVR  VarianceThreshold  480    NaN     NaN     NaN -0.024200
# 77   SVR  VarianceThreshold  485    NaN     NaN     NaN -0.024200
# 78   SVR  VarianceThreshold  490    NaN     NaN     NaN -0.024201
# 79   SVR  VarianceThreshold  495    NaN     NaN     NaN -0.024201
#
#              MAE
# 0   59528.961007
# 1   59528.946382
# 2   59528.946382
# 3   59528.946382
# 4   59528.946382
# ..           ...
# 75  59528.186101
# 76  59528.186101
# 77  59528.186101
# 78  59528.192145
# 79  59528.192145
#
# [80 rows x 8 columns]

# %%
df_last_result=pd.concat([df_var,df_result],axis=0,ignore_index=True)
df_last_result
# Out:
#     Model  feature_selection  NOF Scaler Encoder Imputer        R2  \
# 0     SVR  VarianceThreshold  100    NaN     NaN     NaN -0.024217
# 1     SVR  VarianceThreshold  105    NaN     NaN     NaN -0.024216
# 2     SVR  VarianceThreshold  110    NaN     NaN     NaN -0.024216
# 3     SVR  VarianceThreshold  115    NaN     NaN     NaN -0.024216
# 4     SVR  VarianceThreshold  120    NaN     NaN     NaN -0.024216
# ..    ...                ...  ...    ...     ...     ...       ...
# 98    SVR                UFS   95    NaN     NaN     NaN -0.023994
# 99    SVR                UFS  100    NaN     NaN     NaN -0.024017
# 100   SVR                UFS  105    NaN     NaN     NaN -0.024033
# 101   SVR                UFS  110    NaN     NaN     NaN -0.024059
# 102   SVR                UFS  115    NaN     NaN     NaN -0.024079
#
#               MAE
# 0    59528.961007
# 1    59528.946382
# 2    59528.946382
# 3    59528.946382
# 4    59528.946382
# ..            ...
# 98   59517.010509
# 99   59518.243655
# 100  59519.346637
# 101  59520.557800
# 102  59521.451371
#
# [103 rows x 8 columns]

# %%
df_statistic=pd.read_csv(r"C:\Users\NTCUONG\notebook\cnt-first-project\eda+model_LR\statistic_training_dataset.csv")
df_statistic
# Out:
#            DATASET        ENCODER        IMPUTER    NORMALIZER
# 0    training1.csv   LabelEncoder  simpleimputer          none
# 1    training2.csv   LabelEncoder  simpleimputer    normalizer
# 2    training3.csv   LabelEncoder  simpleimputer  minmaxscaler
# 3    training4.csv   LabelEncoder     knnimputer          none
# 4    training5.csv   LabelEncoder     knnimputer    normalizer
# 5    training6.csv   LabelEncoder     knnimputer  minmaxscaler
# 6    training7.csv  OnehotEncoder  simpleimputer          none
# 7    training8.csv  OnehotEncoder  simpleimputer    normalizer
# 8    training9.csv  OnehotEncoder  simpleimputer  minmaxscaler
# 9   training10.csv  OnehotEncoder     knnimputer          none
# 10  training11.csv  OnehotEncoder     knnimputer    normalizer
# 11  training12.csv  OnehotEncoder     knnimputer  minmaxscaler

# %% [markdown]
# # Note

# %%
df_last_result["Scaler"]="Minmaxscaler"
df_last_result["Encoder"]="OnehotEncoder"
df_last_result["Imputer"]="KnnImputer"
df_last_result
# Out:
#     Model  feature_selection  NOF        Scaler        Encoder     Imputer  \
# 0     SVR  VarianceThreshold  100  Minmaxscaler  OnehotEncoder  KnnImputer
# 1     SVR  VarianceThreshold  105  Minmaxscaler  OnehotEncoder  KnnImputer
# 2     SVR  VarianceThreshold  110  Minmaxscaler  OnehotEncoder  KnnImputer
# 3     SVR  VarianceThreshold  115  Minmaxscaler  OnehotEncoder  KnnImputer
# 4     SVR  VarianceThreshold  120  Minmaxscaler  OnehotEncoder  KnnImputer
# ..    ...                ...  ...           ...            ...         ...
# 98    SVR                UFS   95  Minmaxscaler  OnehotEncoder  KnnImputer
# 99    SVR                UFS  100  Minmaxscaler  OnehotEncoder  KnnImputer
# 100   SVR                UFS  105  Minmaxscaler  OnehotEncoder  KnnImputer
# 101   SVR                UFS  110  Minmaxscaler  OnehotEncoder  KnnImputer
# 102   SVR                UFS  115  Minmaxscaler  OnehotEncoder  KnnImputer
#
#            R2           MAE
# 0   -0.024217  59528.961007
# 1   -0.024216  59528.946382
# 2   -0.024216  59528.946382
# 3   -0.024216  59528.946382
# 4   -0.024216  59528.946382
# ..        ...           ...
# 98  -0.023994  59517.010509
# 99  -0.024017  59518.243655
# 100 -0.024033  59519.346637
# 101 -0.024059  59520.557800
# 102 -0.024079  59521.451371
#
# [103 rows x 8 columns]

# %%
old_df = pd.read_csv("StatisticModel.csv")
old_df
# Out:
#      Model  feature_selection  NOF      Scaler        Encoder        Imputer  \
# 0      SVR  VarianceThreshold  100   Nomalizer   LabelEncoder  SimpleImputer
# 1      SVR  VarianceThreshold  105   Nomalizer   LabelEncoder  SimpleImputer
# 2      SVR  VarianceThreshold  110   Nomalizer   LabelEncoder  SimpleImputer
# 3      SVR  VarianceThreshold  115   Nomalizer   LabelEncoder  SimpleImputer
# 4      SVR  VarianceThreshold  120   Nomalizer   LabelEncoder  SimpleImputer
# ...    ...                ...  ...         ...            ...            ...
# 1025   SVR                UFS   95  Normalizer  OnehotEncoder     KnnImputer
# 1026   SVR                UFS  100  Normalizer  OnehotEncoder     KnnImputer
# 1027   SVR                UFS  105  Normalizer  OnehotEncoder     KnnImputer
# 1028   SVR                UFS  110  Normalizer  OnehotEncoder     KnnImputer
# 1029   SVR                UFS  115  Normalizer  OnehotEncoder     KnnImputer
#
#             R2           MAE
# 0    -0.024790  59559.698541
# 1    -0.024790  59559.698541
# 2    -0.024790  59559.698541
# 3    -0.024790  59559.698541
# 4    -0.024790  59559.698541
# ...        ...           ...
# 1025 -0.024003  59518.720176
# 1026 -0.024041  59520.633910
# 1027 -0.024053  59521.250317
# 1028 -0.024090  59522.704052
# 1029 -0.024103  59523.659724
#
# [1030 rows x 8 columns]

# %%
df_last_result
# Out:
#     Model  feature_selection  NOF        Scaler        Encoder     Imputer  \
# 0     SVR  VarianceThreshold  100  Minmaxscaler  OnehotEncoder  KnnImputer
# 1     SVR  VarianceThreshold  105  Minmaxscaler  OnehotEncoder  KnnImputer
# 2     SVR  VarianceThreshold  110  Minmaxscaler  OnehotEncoder  KnnImputer
# 3     SVR  VarianceThreshold  115  Minmaxscaler  OnehotEncoder  KnnImputer
# 4     SVR  VarianceThreshold  120  Minmaxscaler  OnehotEncoder  KnnImputer
# ..    ...                ...  ...           ...            ...         ...
# 98    SVR                UFS   95  Minmaxscaler  OnehotEncoder  KnnImputer
# 99    SVR                UFS  100  Minmaxscaler  OnehotEncoder  KnnImputer
# 100   SVR                UFS  105  Minmaxscaler  OnehotEncoder  KnnImputer
# 101   SVR                UFS  110  Minmaxscaler  OnehotEncoder  KnnImputer
# 102   SVR                UFS  115  Minmaxscaler  OnehotEncoder  KnnImputer
#
#            R2           MAE
# 0   -0.024217  59528.961007
# 1   -0.024216  59528.946382
# 2   -0.024216  59528.946382
# 3   -0.024216  59528.946382
# 4   -0.024216  59528.946382
# ..        ...           ...
# 98  -0.023994  59517.010509
# 99  -0.024017  59518.243655
# 100 -0.024033  59519.346637
# 101 -0.024059  59520.557800
# 102 -0.024079  59521.451371
#
# [103 rows x 8 columns]

# %%
df_result=pd.concat([old_df,df_last_result],axis=0,ignore_index=True)
df_result
# Out:
#      Model  feature_selection  NOF        Scaler        Encoder  \
# 0      SVR  VarianceThreshold  100     Nomalizer   LabelEncoder
# 1      SVR  VarianceThreshold  105     Nomalizer   LabelEncoder
# 2      SVR  VarianceThreshold  110     Nomalizer   LabelEncoder
# 3      SVR  VarianceThreshold  115     Nomalizer   LabelEncoder
# 4      SVR  VarianceThreshold  120     Nomalizer   LabelEncoder
# ...    ...                ...  ...           ...            ...
# 1128   SVR                UFS   95  Minmaxscaler  OnehotEncoder
# 1129   SVR                UFS  100  Minmaxscaler  OnehotEncoder
# 1130   SVR                UFS  105  Minmaxscaler  OnehotEncoder
# 1131   SVR                UFS  110  Minmaxscaler  OnehotEncoder
# 1132   SVR                UFS  115  Minmaxscaler  OnehotEncoder
#
#             Imputer        R2           MAE
# 0     SimpleImputer -0.024790  59559.698541
# 1     SimpleImputer -0.024790  59559.698541
# 2     SimpleImputer -0.024790  59559.698541
# 3     SimpleImputer -0.024790  59559.698541
# 4     SimpleImputer -0.024790  59559.698541
# ...             ...       ...           ...
# 1128     KnnImputer -0.023994  59517.010509
# 1129     KnnImputer -0.024017  59518.243655
# 1130     KnnImputer -0.024033  59519.346637
# 1131     KnnImputer -0.024059  59520.557800
# 1132     KnnImputer -0.024079  59521.451371
#
# [1133 rows x 8 columns]

# %%
df_result.to_csv("StatisticModel.csv",index=False)

# %%
df=pd.read_csv("StatisticModel.csv")
df
# Out:
#      Model  feature_selection  NOF        Scaler        Encoder  \
# 0      SVR  VarianceThreshold  100     Nomalizer   LabelEncoder
# 1      SVR  VarianceThreshold  105     Nomalizer   LabelEncoder
# 2      SVR  VarianceThreshold  110     Nomalizer   LabelEncoder
# 3      SVR  VarianceThreshold  115     Nomalizer   LabelEncoder
# 4      SVR  VarianceThreshold  120     Nomalizer   LabelEncoder
# ...    ...                ...  ...           ...            ...
# 1128   SVR                UFS   95  Minmaxscaler  OnehotEncoder
# 1129   SVR                UFS  100  Minmaxscaler  OnehotEncoder
# 1130   SVR                UFS  105  Minmaxscaler  OnehotEncoder
# 1131   SVR                UFS  110  Minmaxscaler  OnehotEncoder
# 1132   SVR                UFS  115  Minmaxscaler  OnehotEncoder
#
#             Imputer        R2           MAE
# 0     SimpleImputer -0.024790  59559.698541
# 1     SimpleImputer -0.024790  59559.698541
# 2     SimpleImputer -0.024790  59559.698541
# 3     SimpleImputer -0.024790  59559.698541
# 4     SimpleImputer -0.024790  59559.698541
# ...             ...       ...           ...
# 1128     KnnImputer -0.023994  59517.010509
# 1129     KnnImputer -0.024017  59518.243655
# 1130     KnnImputer -0.024033  59519.346637
# 1131     KnnImputer -0.024059  59520.557800
# 1132     KnnImputer -0.024079  59521.451371
#
# [1133 rows x 8 columns]

# %%
df["Imputer"].unique()
# Out:
# array(['SimpleImputer', 'KnnImputer'], dtype=object)

# %%
# df["Imputer"]=df["Imputer"].apply(lambda x:"SimpleImputer" if x=="Simpleimputer" else x)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(joint["K"],joint["MAE_x"],label="r_regression")
plt.plot(joint["K"],joint["MAE_y"],label="f_regression")
plt.plot(joint["K"],joint["MAE"],label="mutual_infomation")
plt.xlabel("Number of feature")
plt.ylabel("MAE")
plt.title("MAE evaluation") 
plt.legend()
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(joint["K"],joint["r2_x"],label="r_regression")
plt.plot(joint["K"],joint["r2_y"],label="f_regression")
plt.plot(joint["K"],joint["r2"],label="mutual_infomation")
plt.xlabel("Number of feature")
plt.ylabel("MAE")
plt.title("R2 evaluation") 
plt.legend()
