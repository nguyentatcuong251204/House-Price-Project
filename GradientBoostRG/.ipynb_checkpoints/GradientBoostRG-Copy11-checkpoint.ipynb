# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,root_mean_squared_error,r2_score

# %%
df=pd.read_csv(r"C:\Users\NTCUONG\notebook\training_LR\training10.csv")
df.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.150094     0.245503  0.823713     0.467041     0.277781   0.452097
# 1    0.043703     0.275451  0.858747     0.357852     0.408238   0.401561
# 2    0.118369     0.200515  0.890164     0.365548     0.217228   0.353258
# 3    0.159661     0.203803  0.859960     0.423637     0.251885   0.391060
# 4    0.094960     0.199563  0.918120     0.335099     0.172546   0.280525
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_WD  \
# 0      0.448408    0.101483    0.326545         0.0  ...     0.456083
# 1      0.398284    0.000000    0.409536         0.0  ...     0.412913
# 2      0.350562    0.066415    0.177987         0.0  ...     0.361126
# 3      0.399603    0.000000    0.091011         0.0  ...     0.415474
# 4      0.278236    0.115649    0.193337         0.0  ...     0.291058
#
#    SaleType_nan  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# 0             0               0.000000                    0.0
# 1             0               0.000000                    0.0
# 2             0               0.000000                    0.0
# 3             0               0.417033                    0.0
# 4             0               0.000000                    0.0
#
#    SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# 0                   0.0                   0.0              0.456083
# 1                   0.0                   0.0              0.412913
# 2                   0.0                   0.0              0.361126
# 3                   0.0                   0.0              0.000000
# 4                   0.0                   0.0              0.291058
#
#    SaleCondition_Partial  SaleCondition_nan  SalePrice
# 0                    0.0                  0     208500
# 1                    0.0                  0     181500
# 2                    0.0                  0     223500
# 3                    0.0                  0     140000
# 4                    0.0                  0     250000
#
# [5 rows x 305 columns]

# %%
corr=df.corr()

# %%
df.corr().sort_values("SalePrice",ascending=False).head(10)
# Out:
#                       MSSubClass  LotFrontage   LotArea  OverallQual  \
# SalePrice              -0.187647    -0.150612  0.228492     0.030433
# BsmtQual_Ex            -0.019162     0.029625 -0.004661     0.153260
# KitchenQual_Ex         -0.008671    -0.015889 -0.001595     0.123222
# ExterQual_Ex           -0.043465    -0.002081  0.037454     0.084736
# Neighborhood_NridgHt    0.079830     0.011417 -0.060334     0.180990
# ExterQual_Gd            0.244144     0.127291 -0.271118     0.500648
# Foundation_PConc        0.294030     0.138138 -0.309576     0.539514
# Fireplaces              0.063250     0.047981 -0.071323     0.203926
# Neighborhood_NoRidge   -0.053253     0.002040  0.061684    -0.005377
# MasVnrArea              0.226652     0.020592 -0.232376     0.282195
#
#                       OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# SalePrice               -0.394900  -0.393929     -0.401973    0.286089
# BsmtQual_Ex             -0.114671  -0.048726     -0.053646    0.226263
# KitchenQual_Ex          -0.057121  -0.059439     -0.059953    0.120338
# ExterQual_Ex            -0.084612  -0.086550     -0.088374    0.216657
# Neighborhood_NridgHt    -0.053661   0.014349      0.010042    0.207970
# ExterQual_Gd             0.062334   0.222969      0.213852    0.138024
# Foundation_PConc         0.079992   0.286325      0.275757    0.187246
# Fireplaces              -0.014197   0.007862      0.003995    0.146287
# Neighborhood_NoRidge    -0.120317  -0.107713     -0.110160    0.197925
# MasVnrArea               0.032106   0.138909      0.130019    1.000000
#
#                       BsmtFinSF1  BsmtFinSF2  ...  SaleType_WD  SaleType_nan  \
# SalePrice               0.209935   -0.056868  ...    -0.423426           NaN
# BsmtQual_Ex             0.196354   -0.036025  ...    -0.206695           NaN
# KitchenQual_Ex          0.146168   -0.038462  ...    -0.133922           NaN
# ExterQual_Ex            0.111300   -0.034108  ...    -0.192771           NaN
# Neighborhood_NridgHt    0.098621   -0.051179  ...    -0.091817           NaN
# ExterQual_Gd            0.093554   -0.080887  ...     0.020290           NaN
# Foundation_PConc        0.134822   -0.131092  ...     0.067493           NaN
# Fireplaces              0.132208   -0.002821  ...    -0.008842           NaN
# Neighborhood_NoRidge    0.082584   -0.044654  ...    -0.039500           NaN
# MasVnrArea              0.209548   -0.087016  ...     0.046362           NaN
#
#                       SaleCondition_Abnorml  SaleCondition_AdjLand  \
# SalePrice                         -0.139545              -0.051458
# BsmtQual_Ex                       -0.045265              -0.014686
# KitchenQual_Ex                     0.049378              -0.013164
# ExterQual_Ex                      -0.046799              -0.009523
# Neighborhood_NridgHt              -0.056647              -0.011527
# ExterQual_Gd                      -0.045175              -0.033648
# Foundation_PConc                  -0.068619               0.020954
# Fireplaces                        -0.092457              -0.046835
# Neighborhood_NoRidge              -0.001196              -0.008586
# MasVnrArea                        -0.007775              -0.012815
#
#                       SaleCondition_Alloca  SaleCondition_Family  \
# SalePrice                        -0.030231             -0.049619
# BsmtQual_Ex                      -0.024430             -0.031567
# KitchenQual_Ex                   -0.021899             -0.028297
# ExterQual_Ex                     -0.015841             -0.020469
# Neighborhood_NridgHt             -0.019174             -0.024776
# ExterQual_Gd                     -0.050994             -0.038926
# Foundation_PConc                 -0.042032             -0.034403
# Fireplaces                       -0.022880             -0.004424
# Neighborhood_NoRidge             -0.014284             -0.018456
# MasVnrArea                        0.015781              0.050269
#
#                       SaleCondition_Normal  SaleCondition_Partial  \
# SalePrice                        -0.338044               0.273673
# BsmtQual_Ex                      -0.170257               0.307506
# KitchenQual_Ex                   -0.165153               0.190471
# ExterQual_Ex                     -0.160383               0.240313
# Neighborhood_NridgHt             -0.048898               0.173688
# ExterQual_Gd                      0.054771               0.242718
# Foundation_PConc                  0.078990               0.286249
# Fireplaces                        0.044421               0.036288
# Neighborhood_NoRidge             -0.044507              -0.047499
# MasVnrArea                        0.038061               0.075631
#
#                       SaleCondition_nan  SalePrice
# SalePrice                           NaN   1.000000
# BsmtQual_Ex                         NaN   0.451608
# KitchenQual_Ex                      NaN   0.409421
# ExterQual_Ex                        NaN   0.404878
# Neighborhood_NridgHt                NaN   0.313647
# ExterQual_Gd                        NaN   0.307234
# Foundation_PConc                    NaN   0.306703
# Fireplaces                          NaN   0.296400
# Neighborhood_NoRidge                NaN   0.292830
# MasVnrArea                          NaN   0.286089
#
# [10 rows x 305 columns]

# %%
def create_df(col_list):
    df_fs=df["SalePrice"]
    for col in col_list:
        df_fs=pd.concat([df[col],df_fs],axis=1)
    return df_fs

# %%
model=GradientBoostingRegressor()

# %%
def eval(df_fs):
    X_train,X_test,y_train,y_test=train_test_split(df_fs.iloc[:,:-1],df_fs.iloc[:,-1],test_size=0.2,random_state=42)
    model.fit(X_train,y_train)
    y_pre=model.predict(X_test)
    k.append(i)
    mae.append(mean_absolute_error(y_test,y_pre))
    rmse.append(root_mean_squared_error(y_test,y_pre))
    r2.append(r2_score(y_test,y_pre))

# %% [markdown]
# ### FEATURE SELECTION DEPEND ON CORRELATION MATRIX

# %% [markdown]
# plt.figure(figsize=(12,10))
# sns.heatmap(df.corr(),cmap='coolwarm')

# %%
c=corr.sort_values("SalePrice",ascending=False).head(10).index
c
# Out:
# Index(['SalePrice', 'BsmtQual_Ex', 'KitchenQual_Ex', 'ExterQual_Ex',
#        'Neighborhood_NridgHt', 'ExterQual_Gd', 'Foundation_PConc',
#        'Fireplaces', 'Neighborhood_NoRidge', 'MasVnrArea'],
#       dtype='object')

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(10,120):
    c=corr.sort_values("SalePrice",ascending=False).iloc[1:i,:].index
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic
# Out:
#        K           MAE          RMSE        r2
# 0     10  28942.526169  39915.144672  0.792288
# 1     11  29171.085141  41080.444567  0.779983
# 2     12  28624.666928  40115.915425  0.790193
# 3     13  28093.523543  39509.577172  0.796488
# 4     14  28256.092370  39653.140909  0.795006
# ..   ...           ...           ...       ...
# 105  115  22060.143221  31782.625789  0.868306
# 106  116  22002.050286  31679.514749  0.869159
# 107  117  21984.307011  31715.089862  0.868865
# 108  118  22053.042352  31767.965935  0.868428
# 109  119  22028.573870  31726.341580  0.868772
#
# [110 rows x 4 columns]

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#      K           MAE          RMSE        r2
# 18  28  21461.940173  30145.643120  0.881523
# 53  63  21471.664852  30970.595701  0.874950
# 50  60  21488.508852  30926.938158  0.875302
# 61  71  21526.600685  31267.729935  0.872539
# 52  62  21528.026559  31054.934315  0.874268
# ..  ..           ...           ...       ...
# 3   13  28093.523543  39509.577172  0.796488
# 4   14  28256.092370  39653.140909  0.795006
# 2   12  28624.666928  40115.915425  0.790193
# 0   10  28942.526169  39915.144672  0.792288
# 1   11  29171.085141  41080.444567  0.779983
#
# [110 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### FEATURE SELECTION BY REMOVE FEATURE WITH LOW VARIENCE

# %% [markdown]
# ### 1.CALCULATE VARIENCE FOR EACH FEATURE

# %%
varr=np.var(df)
varr
# Out:
# D:\miniconda\lib\site-packages\numpy\core\fromnumeric.py:3785: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# MSSubClass               3.261382e-02
# LotFrontage              5.107832e-03
# LotArea                  2.617346e-02
# OverallQual              2.393219e-02
# OverallCond              1.685412e-02
#                              ...
# SaleCondition_Family     3.132392e-03
# SaleCondition_Normal     4.913976e-02
# SaleCondition_Partial    2.113360e-02
# SaleCondition_nan        0.000000e+00
# SalePrice                6.306789e+09
# Length: 305, dtype: float64

# %%
varr.loc[varr > 0.1].index
# Out:
# Index(['SalePrice'], dtype='object')

# %% [markdown]
# ### 2.USING VarianceThreshold FROM SKLEARN

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
varr_thresh=VarianceThreshold(threshold=0.1)
varr_thresh.fit_transform(df)
selected_columns = df.columns[varr_thresh.get_support()]
selected_columns
# Out:
# Index(['SalePrice'], dtype='object')

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(100,500):
    varr_thresh=VarianceThreshold(threshold=i/100000)
    varr_thresh.fit_transform(df.iloc[:,:-1])
    selected_columns = df.iloc[:,:-1].columns[varr_thresh.get_support()]
    df_fs=create_df(selected_columns)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic
# Out:
#        K           MAE          RMSE        r2
# 0    100  19480.885936  29605.434771  0.885731
# 1    101  19464.241124  29763.610520  0.884507
# 2    102  19431.633662  29645.000232  0.885425
# 3    103  19541.252445  29767.493242  0.884476
# 4    104  19438.389834  29771.706380  0.884444
# ..   ...           ...           ...       ...
# 395  495  19264.833856  30914.073579  0.875406
# 396  496  19265.132889  30611.419953  0.877833
# 397  497  19429.382639  31106.794575  0.873847
# 398  498  19326.568008  30746.658149  0.876751
# 399  499  19265.991135  30527.152948  0.878505
#
# [400 rows x 4 columns]

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#        K           MAE          RMSE        r2
# 386  486  19171.960399  30534.594780  0.878446
# 329  429  19194.865655  30807.699361  0.876262
# 311  411  19197.996980  30706.517259  0.877073
# 260  360  19202.862448  30450.800279  0.879112
# 368  468  19212.804450  30495.904395  0.878754
# ..   ...           ...           ...       ...
# 67   167  19753.137203  30648.228846  0.877539
# 80   180  19778.428242  30838.896573  0.876011
# 78   178  19789.016710  30822.275851  0.876144
# 88   188  19809.663444  30789.385805  0.876409
# 91   191  19824.904225  31178.966558  0.873261
#
# [400 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x=statistic["K"]/1000,y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x=statistic["K"]/1000,y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\873788412.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\873788412.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### Univariate feature selection

# %% [markdown]
# ### Statistic function (r_regression, f_regression, mutual_info_regression)

# %% [markdown]
# ### 1. r_regression

# %% [markdown]
# ![image.png](attachment:f483b42b-de90-46a8-afcd-444eb978b015.png)

# %% [markdown]
# ### Using numpy

# %%
def similitary_score(x,y):
    x_avg=np.average(x)
    y_avg=np.average(y)
    up=np.sum((x-x_avg)*(y-y_avg))
    down=np.sqrt(np.sum((x-x_avg)**2)*np.sum((y-y_avg)**2))
    return up/down

# %%
print(similitary_score(df["OverallQual"],df["SalePrice"]))
# Out:
# 0.0304326175489076

# %%
top_feature=[]
for col in df.columns:
    score=similitary_score(df[col],df["SalePrice"])
    if col != "SalePrice" and score > 0.6:
        top_feature.append([col,score])
top_feature
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\2326211799.py:6: RuntimeWarning: invalid value encountered in scalar divide
#   return up/down
# []

# %% [markdown]
# ### Using sklearn

# %%
from sklearn.feature_selection import r_regression
from sklearn.feature_selection import SelectKBest
# for i in range(5,21):
fs=SelectKBest(r_regression,k=6)
fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
# selected=df.columns[fs.get_support()]
fs.get_feature_names_out()
# Out:
# array(['Neighborhood_NridgHt', 'ExterQual_Ex', 'ExterQual_Gd',
#        'Foundation_PConc', 'BsmtQual_Ex', 'KitchenQual_Ex'], dtype=object)

# %%
k, mae, rmse, r2 = [], [], [], []

for i in range(5,120):
    fs=SelectKBest(r_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic.to_csv("r_regression_label_enc.csv")
statistic
# Out:
#        K           MAE          RMSE        r2
# 0      5  35876.646200  50917.319281  0.662000
# 1      6  34629.556391  49966.369288  0.674507
# 2      7  31559.072202  45846.135774  0.725974
# 3      8  30208.537997  41953.739470  0.770529
# 4      9  28948.737636  39917.632497  0.792262
# ..   ...           ...           ...       ...
# 110  115  21784.170127  31693.305231  0.869045
# 111  116  21825.716170  31753.481261  0.868547
# 112  117  22114.078319  32001.003285  0.866490
# 113  118  22088.821622  32081.777223  0.865815
# 114  119  22113.056221  32017.229905  0.866355
#
# [115 rows x 4 columns]

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#      K           MAE          RMSE        r2
# 22  27  21453.602917  30106.511514  0.881830
# 54  59  21468.431762  30905.732806  0.875473
# 55  60  21496.489570  30999.442326  0.874716
# 65  70  21518.417401  31219.733674  0.872930
# 35  40  21535.376108  30576.161437  0.878114
# ..  ..           ...           ...       ...
# 5   10  29157.948091  41063.183818  0.780168
# 3    8  30208.537997  41953.739470  0.770529
# 2    7  31559.072202  45846.135774  0.725974
# 1    6  34629.556391  49966.369288  0.674507
# 0    5  35876.646200  50917.319281  0.662000
#
# [115 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### 2.f_regression

# %% [markdown]
# ![image.png](attachment:95f14443-0240-442c-b294-562b150eb8bd.png)

# %% [markdown]
# ![image.png](attachment:a344f6dc-6cf9-490d-a595-9c80c9c1128a.png)

# %%
from sklearn.feature_selection import f_regression

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(5,120):
    fs=SelectKBest(f_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic.to_csv("f_regression_label_enc.csv")
statistic
# Out:
#        K           MAE          RMSE        r2
# 0      5  34240.513899  50676.376304  0.665191
# 1      6  33469.878306  50038.254020  0.673570
# 2      7  32003.086794  47607.562515  0.704513
# 3      8  31295.165256  46592.238479  0.716982
# 4      9  31330.673134  46243.035992  0.721209
# ..   ...           ...           ...       ...
# 110  115  19416.035994  29934.017087  0.883180
# 111  116  19651.488184  30531.230998  0.878472
# 112  117  19638.935615  30809.961637  0.876243
# 113  118  19607.091561  30929.689789  0.875280
# 114  119  19996.729602  30880.064999  0.875680
#
# [115 rows x 4 columns]

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#        K           MAE          RMSE        r2
# 110  115  19416.035994  29934.017087  0.883180
# 108  113  19595.347839  30393.031974  0.879570
# 72    77  19604.721494  30619.260925  0.877771
# 71    76  19606.923721  30470.266208  0.878957
# 113  118  19607.091561  30929.689789  0.875280
# ..   ...           ...           ...       ...
# 3      8  31295.165256  46592.238479  0.716982
# 4      9  31330.673134  46243.035992  0.721209
# 2      7  32003.086794  47607.562515  0.704513
# 1      6  33469.878306  50038.254020  0.673570
# 0      5  34240.513899  50676.376304  0.665191
#
# [115 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### 3.Mutual infomation

# %% [markdown]
# ### Fomula

# %% [markdown]
# ![image.png](attachment:283a97b8-8534-4c70-8086-d6b229834262.png)

# %% [markdown]
# ### Mesure dependency of 2 variable X,Y

# %% [markdown]
# ### KDE method (Estimate Probability Density Function)

# %% [markdown]
# ![image.png](attachment:d3173b36-c1e3-421a-a817-095dbfd9041c.png)

# %% [markdown]
# ![image.png](attachment:88044c6a-ccc1-4d54-bbb2-f410d59aa145.png)

# %% [markdown]
# ![image.png](attachment:5c8079a5-deea-43ef-85ff-0e46935b227e.png)

# %%
all_col=df.columns
all_col
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        ...
#        'SaleType_WD', 'SaleType_nan', 'SaleCondition_Abnorml',
#        'SaleCondition_AdjLand', 'SaleCondition_Alloca', 'SaleCondition_Family',
#        'SaleCondition_Normal', 'SaleCondition_Partial', 'SaleCondition_nan',
#        'SalePrice'],
#       dtype='object', length=305)

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(5,120):
    fs=SelectKBest(mutual_info_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic
# Out:
#        K           MAE          RMSE        r2
# 0      5  33457.415434  52382.170083  0.642272
# 1      6  33141.884131  51517.200353  0.653988
# 2      7  31977.130857  49426.760315  0.681499
# 3      8  32535.383793  50338.406690  0.669642
# 4      9  31899.401629  49367.269455  0.682265
# ..   ...           ...           ...       ...
# 110  115  19951.127480  30121.192198  0.881715
# 111  116  19676.141452  30130.912341  0.881638
# 112  117  19865.474002  29949.970160  0.883056
# 113  118  19186.831350  30040.572469  0.882347
# 114  119  19948.576254  32556.241123  0.861817
#
# [115 rows x 4 columns]

# %%
statistic.to_csv("mutual_infomation_label_enc.csv")

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#        K           MAE          RMSE        r2
# 113  118  19186.831350  30040.572469  0.882347
# 101  106  19298.138942  30839.862459  0.876003
# 98   103  19399.818105  31196.286961  0.873120
# 107  112  19460.437441  30705.717521  0.877079
# 106  111  19493.859708  31020.610650  0.874545
# ..   ...           ...           ...       ...
# 7     12  32166.125401  48516.973070  0.693116
# 9     14  32183.237931  49280.614335  0.683380
# 3      8  32535.383793  50338.406690  0.669642
# 1      6  33141.884131  51517.200353  0.653988
# 0      5  33457.415434  52382.170083  0.642272
#
# [115 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_23000\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### RFE (Recursive feature elimination)

# %% [markdown]
# df

# %% [markdown]
# from sklearn.feature_selection import RFE,RFECV
# rfe=RFE(estimator=model,n_features_to_select=5)
# rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
# rfe.get_feature_names_out()

# %% [markdown]
# k, mae, rmse, r2 = [], [], [], []
# for i in range(10,50):
#     rfe=RFE(estimator=model,n_features_to_select=i)
#     rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
#     c = df.iloc[:,:-1].columns[rfe.support_]
#     df_fs=create_df(c)
#     eval(df_fs)
# statistic_tup={
#     "K":k,
#     "MAE":mae,
#     "RMSE":rmse,
#     "r2":r2
# }
# statistic=pd.DataFrame(statistic_tup)
# statistic

# %% [markdown]
# statistic.to_csv("RFE.csv")

# %% [markdown]
# statistic=pd.read_csv("RFE.csv")

# %% [markdown]
# fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
# ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
# ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
# ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
# plt.show()

# %% [markdown]
# k, mae, rmse, r2 = [], [], [], []
# for i in range(10,15):
#     rfe=RFECV(estimator=model,min_features_to_select=i,cv=5)
#     rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
#     c = df.iloc[:,:-1].columns[rfe.support_]
#     df_fs=create_df(c)
#     eval(df_fs)
# statistic_tup={
#     "K":k,
#     "MAE":mae,
#     "RMSE":rmse,
#     "r2":r2
# }
# statistic=pd.DataFrame(statistic_tup)
# statistic

# %% [markdown]
# fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
# ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
# ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
# ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
# plt.show()

# %% [markdown]
# statistic.to_csv("RFECV.csv")

# %%
r=pd.read_csv("r_regression_label_enc.csv")
r=r.iloc[:,1:]
r
# Out:
#        K           MAE          RMSE        r2
# 0      5  35890.359891  50901.949232  0.662204
# 1      6  34660.461597  50002.241821  0.674039
# 2      7  31564.708773  45860.413561  0.725803
# 3      8  30212.362959  41950.167250  0.770568
# 4      9  28986.486315  40015.679080  0.791240
# ..   ...           ...           ...       ...
# 110  115  21814.597153  31668.144146  0.869253
# 111  116  21786.549622  31645.795929  0.869438
# 112  117  22088.993428  31976.786881  0.866692
# 113  118  22124.740073  32005.206735  0.866455
# 114  119  22119.367556  32109.627768  0.865582
#
# [115 rows x 4 columns]

# %%
f=pd.read_csv("f_regression_label_enc.csv")
f=f.iloc[:,1:]
f
# Out:
#        K           MAE          RMSE        r2
# 0      5  34354.505424  51440.370481  0.655020
# 1      6  33572.804895  50895.643927  0.662287
# 2      7  31998.620106  47606.662232  0.704524
# 3      8  31284.920167  46590.490643  0.717004
# 4      9  31376.756052  46259.713117  0.721008
# ..   ...           ...           ...       ...
# 110  115  19547.763778  30557.023160  0.878267
# 111  116  19783.132247  31223.937471  0.872895
# 112  117  19642.594200  30488.959965  0.878809
# 113  118  19589.283325  30425.147489  0.879315
# 114  119  20157.983155  31699.250827  0.868996
#
# [115 rows x 4 columns]

# %%
mutual=pd.read_csv("mutual_infomation_label_enc.csv")
mutual=mutual.iloc[:,1:]
mutual
# Out:
#        K           MAE          RMSE        r2
# 0      5  33457.415434  52382.170083  0.642272
# 1      6  33141.884131  51517.200353  0.653988
# 2      7  31977.130857  49426.760315  0.681499
# 3      8  32535.383793  50338.406690  0.669642
# 4      9  31899.401629  49367.269455  0.682265
# ..   ...           ...           ...       ...
# 110  115  19951.127480  30121.192198  0.881715
# 111  116  19676.141452  30130.912341  0.881638
# 112  117  19865.474002  29949.970160  0.883056
# 113  118  19186.831350  30040.572469  0.882347
# 114  119  19948.576254  32556.241123  0.861817
#
# [115 rows x 4 columns]

# %%
joint=pd.merge(r,f,how='inner',on="K")
joint
# Out:
#        K         MAE_x        RMSE_x      r2_x         MAE_y        RMSE_y  \
# 0      5  35890.359891  50901.949232  0.662204  34354.505424  51440.370481
# 1      6  34660.461597  50002.241821  0.674039  33572.804895  50895.643927
# 2      7  31564.708773  45860.413561  0.725803  31998.620106  47606.662232
# 3      8  30212.362959  41950.167250  0.770568  31284.920167  46590.490643
# 4      9  28986.486315  40015.679080  0.791240  31376.756052  46259.713117
# ..   ...           ...           ...       ...           ...           ...
# 110  115  21814.597153  31668.144146  0.869253  19547.763778  30557.023160
# 111  116  21786.549622  31645.795929  0.869438  19783.132247  31223.937471
# 112  117  22088.993428  31976.786881  0.866692  19642.594200  30488.959965
# 113  118  22124.740073  32005.206735  0.866455  19589.283325  30425.147489
# 114  119  22119.367556  32109.627768  0.865582  20157.983155  31699.250827
#
#          r2_y
# 0    0.655020
# 1    0.662287
# 2    0.704524
# 3    0.717004
# 4    0.721008
# ..        ...
# 110  0.878267
# 111  0.872895
# 112  0.878809
# 113  0.879315
# 114  0.868996
#
# [115 rows x 7 columns]

# %%
joint=pd.merge(joint,mutual,on="K",how="inner")
joint
# Out:
#        K         MAE_x        RMSE_x      r2_x         MAE_y        RMSE_y  \
# 0      5  35890.359891  50901.949232  0.662204  34354.505424  51440.370481
# 1      6  34660.461597  50002.241821  0.674039  33572.804895  50895.643927
# 2      7  31564.708773  45860.413561  0.725803  31998.620106  47606.662232
# 3      8  30212.362959  41950.167250  0.770568  31284.920167  46590.490643
# 4      9  28986.486315  40015.679080  0.791240  31376.756052  46259.713117
# ..   ...           ...           ...       ...           ...           ...
# 110  115  21814.597153  31668.144146  0.869253  19547.763778  30557.023160
# 111  116  21786.549622  31645.795929  0.869438  19783.132247  31223.937471
# 112  117  22088.993428  31976.786881  0.866692  19642.594200  30488.959965
# 113  118  22124.740073  32005.206735  0.866455  19589.283325  30425.147489
# 114  119  22119.367556  32109.627768  0.865582  20157.983155  31699.250827
#
#          r2_y           MAE          RMSE        r2
# 0    0.655020  33457.415434  52382.170083  0.642272
# 1    0.662287  33141.884131  51517.200353  0.653988
# 2    0.704524  31977.130857  49426.760315  0.681499
# 3    0.717004  32535.383793  50338.406690  0.669642
# 4    0.721008  31899.401629  49367.269455  0.682265
# ..        ...           ...           ...       ...
# 110  0.878267  19951.127480  30121.192198  0.881715
# 111  0.872895  19676.141452  30130.912341  0.881638
# 112  0.878809  19865.474002  29949.970160  0.883056
# 113  0.879315  19186.831350  30040.572469  0.882347
# 114  0.868996  19948.576254  32556.241123  0.861817
#
# [115 rows x 10 columns]

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(joint["K"],joint["MAE_x"],label="r_regression")
plt.plot(joint["K"],joint["MAE_y"],label="f_regression")
plt.plot(joint["K"],joint["MAE"],label="mutual_infomation")
plt.xlabel("Number of feature")
plt.ylabel("MAE")
plt.title("MAE evaluation") 
plt.legend()
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(joint["K"],joint["r2_x"],label="r_regression")
plt.plot(joint["K"],joint["r2_y"],label="f_regression")
plt.plot(joint["K"],joint["r2"],label="mutual_infomation")
plt.xlabel("Number of feature")
plt.ylabel("MAE")
plt.title("R2 evaluation") 
plt.legend()
