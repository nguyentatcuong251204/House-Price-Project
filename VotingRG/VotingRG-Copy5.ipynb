# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
from sklearn.metrics import mean_absolute_error,root_mean_squared_error,r2_score

# %%
df=pd.read_csv(r"C:\Users\NTCUONG\notebook\training_LR\training5.csv")
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea    Street  LotShape  \
# 0    0.051008  0.116246     0.083432  0.279926  0.154995  0.154995
# 1    0.016630  0.117844     0.104817  0.326772  0.157125  0.157125
# 2    0.049759  0.113855     0.084291  0.374195  0.151807  0.000000
# 3    0.058532  0.114235     0.074714  0.315258  0.152313  0.000000
# 4    0.044571  0.102460     0.093669  0.430932  0.136614  0.000000
#
#    LandContour  Utilities  LotConfig  LandSlope  ...  3SsnPorch  ScreenPorch  \
# 0     0.154995        0.0   0.154995        0.0  ...        0.0          0.0
# 1     0.157125        0.0   0.078562        0.0  ...        0.0          0.0
# 2     0.151807        0.0   0.151807        0.0  ...        0.0          0.0
# 3     0.152313        0.0   0.000000        0.0  ...        0.0          0.0
# 4     0.136614        0.0   0.068307        0.0  ...        0.0          0.0
#
#    PoolArea  MiscVal    MoSold    YrSold  SaleType  SaleCondition  Ageofhouse  \
# 0       0.0      0.0  0.024965  0.150983  0.154995       0.149656    0.009289
# 1       0.0      0.0  0.066107  0.152226  0.157125       0.151713    0.058385
# 2       0.0      0.0  0.116390  0.146049  0.151807       0.146578    0.012738
# 3       0.0      0.0  0.024340  0.147534  0.152313       0.000000    0.166141
# 4       0.0      0.0  0.139862  0.129529  0.136614       0.131908    0.013100
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 75 columns]

# %%
corr=df.corr()

# %%
df.corr().sort_values("SalePrice",ascending=False).head(10)
# Out:
#              MSSubClass  MSZoning  LotFrontage   LotArea    Street  LotShape  \
# SalePrice     -0.149958 -0.395050     0.113581  0.317537 -0.488240 -0.317057
# GrLivArea      0.109397 -0.208915     0.099421 -0.015611 -0.224525 -0.168171
# GarageArea    -0.102609 -0.272965     0.163152  0.069512 -0.206190 -0.167510
# GarageCars    -0.025598 -0.226690     0.131242  0.014013 -0.165928 -0.177420
# TotalBsmtSF   -0.254642 -0.150886     0.175788  0.059492 -0.126953 -0.170931
# OverallQual    0.158913 -0.069057     0.056226 -0.338996  0.145592 -0.086879
# 1stFlrSF      -0.244680 -0.102913     0.205277  0.009925 -0.105627 -0.135931
# MasVnrArea     0.024757 -0.156048     0.043841  0.025674 -0.192391 -0.113695
# Fireplaces    -0.061848 -0.126831     0.074122  0.179437 -0.233658 -0.209772
# FullBath       0.166597 -0.228867     0.023200 -0.132801 -0.062543 -0.136374
#
#              LandContour  Utilities  LotConfig  LandSlope  ...  3SsnPorch  \
# SalePrice      -0.200098  -0.014314  -0.165933   0.005742  ...   0.042390
# GrLivArea      -0.128206  -0.020050  -0.100007  -0.048385  ...   0.007700
# GarageArea     -0.007230   0.000376  -0.087617  -0.063508  ...   0.027967
# GarageCars     -0.005890   0.001519  -0.085281  -0.069889  ...   0.027165
# TotalBsmtSF     0.001812  -0.022100  -0.037908  -0.047332  ...   0.030134
# OverallQual     0.110167  -0.016284   0.046199  -0.166283  ...   0.006592
# 1stFlrSF       -0.032153   0.002520  -0.040561  -0.039258  ...   0.042364
# MasVnrArea     -0.023828   0.060766  -0.054439  -0.049446  ...   0.018037
# Fireplaces     -0.134864   0.013120  -0.094607   0.033067  ...   0.008254
# FullBath        0.037362  -0.034132   0.003399  -0.118610  ...   0.025886
#
#              ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SaleType  \
# SalePrice       0.090962  0.085395 -0.026840 -0.098794 -0.573913 -0.307684
# GrLivArea       0.052381  0.053335 -0.037432 -0.011940 -0.271855 -0.175348
# GarageArea      0.018784 -0.006017 -0.042975 -0.030864 -0.209394 -0.180956
# GarageCars      0.015425 -0.017865 -0.060124 -0.016287 -0.172838 -0.147486
# TotalBsmtSF     0.062056  0.009560 -0.043781 -0.016115 -0.159271 -0.161371
# OverallQual     0.005374 -0.027426 -0.061161  0.091586  0.161213  0.009252
# 1stFlrSF        0.054946  0.018800 -0.055110  0.003352 -0.132602 -0.181235
# MasVnrArea      0.053694 -0.018137 -0.033129 -0.054778 -0.213859 -0.144448
# Fireplaces      0.169294  0.050150 -0.006998 -0.028060 -0.284568 -0.110770
# FullBath       -0.061983 -0.011930 -0.036091  0.019664 -0.081209 -0.083164
#
#              SaleCondition  Ageofhouse  SalePrice
# SalePrice        -0.001034   -0.571548   1.000000
# GrLivArea        -0.041676   -0.228113   0.589120
# GarageArea        0.078789   -0.504633   0.505566
# GarageCars        0.097013   -0.558473   0.504552
# TotalBsmtSF       0.024657   -0.400962   0.500621
# OverallQual       0.185739   -0.498392   0.488216
# 1stFlrSF         -0.006951   -0.282207   0.436239
# MasVnrArea       -0.013854   -0.322663   0.426354
# Fireplaces       -0.000086   -0.176910   0.399534
# FullBath          0.089712   -0.480101   0.395909
#
# [10 rows x 75 columns]

# %%
def create_df(col_list):
    df_fs=df["SalePrice"]
    for col in col_list:
        df_fs=pd.concat([df[col],df_fs],axis=1)
    return df_fs

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor(random_state=42)
rf = RandomForestRegressor(n_estimators=10, random_state=42)
svr = SVR(kernel='rbf')

model = VotingRegressor(estimators=[
    ('lr', lr),
    ('dt', dt),
    ('rf', rf),
    ('svr', svr)
])

# %%
def eval(df_fs):
    X_train,X_test,y_train,y_test=train_test_split(df_fs.iloc[:,:-1],df_fs.iloc[:,-1],test_size=0.2,random_state=42)
    model.fit(X_train,y_train)
    y_pre=model.predict(X_test)
    k.append(i)
    mae.append(mean_absolute_error(y_test,y_pre))
    rmse.append(root_mean_squared_error(y_test,y_pre))
    r2.append(r2_score(y_test,y_pre))

# %% [markdown]
# ### FEATURE SELECTION DEPEND ON CORRELATION MATRIX

# %% [markdown]
# plt.figure(figsize=(12,10))
# sns.heatmap(df.corr(),cmap='coolwarm')

# %%
c=corr.sort_values("SalePrice",ascending=False).head(10).index
c
# Out:
# Index(['SalePrice', 'GrLivArea', 'GarageArea', 'GarageCars', 'TotalBsmtSF',
#        'OverallQual', '1stFlrSF', 'MasVnrArea', 'Fireplaces', 'FullBath'],
#       dtype='object')

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(10,120):
    c=corr.sort_values("SalePrice",ascending=False).iloc[1:i,:].index
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic
# Out:
#        K           MAE          RMSE        r2
# 0     10  30340.150976  51342.535436  0.656331
# 1     11  28819.760287  49217.476180  0.684191
# 2     12  26940.693423  47267.131967  0.708724
# 3     13  26756.462928  46712.676029  0.715517
# 4     14  26944.074277  47039.949193  0.711517
# ..   ...           ...           ...       ...
# 105  115  23156.532414  41536.885310  0.775067
# 106  116  23156.532414  41536.885310  0.775067
# 107  117  23156.532414  41536.885310  0.775067
# 108  118  23156.532414  41536.885310  0.775067
# 109  119  23156.532414  41536.885310  0.775067
#
# [110 rows x 4 columns]

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#        K           MAE          RMSE        r2
# 109  119  23156.532414  41536.885310  0.775067
# 86    96  23156.532414  41536.885310  0.775067
# 85    95  23156.532414  41536.885310  0.775067
# 108  118  23156.532414  41536.885310  0.775067
# 65    75  23156.532414  41536.885310  0.775067
# ..   ...           ...           ...       ...
# 11    21  27194.809236  47082.552075  0.710994
# 5     15  27413.286814  47986.609080  0.699789
# 6     16  27505.373848  48201.486427  0.697095
# 1     11  28819.760287  49217.476180  0.684191
# 0     10  30340.150976  51342.535436  0.656331
#
# [110 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### FEATURE SELECTION BY REMOVE FEATURE WITH LOW VARIENCE

# %% [markdown]
# ### 1.CALCULATE VARIENCE FOR EACH FEATURE

# %%
varr=np.var(df)
varr
# Out:
# D:\miniconda\lib\site-packages\numpy\core\fromnumeric.py:3785: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# MSSubClass       1.421058e-03
# MSZoning         8.135175e-04
# LotFrontage      6.080463e-04
# LotArea          1.746308e-02
# Street           3.336710e-04
#                      ...
# YrSold           3.250450e-04
# SaleType         1.130013e-03
# SaleCondition    1.792836e-03
# Ageofhouse       3.218771e-03
# SalePrice        6.306789e+09
# Length: 75, dtype: float64

# %%
varr.loc[varr > 0.1].index
# Out:
# Index(['SalePrice'], dtype='object')

# %% [markdown]
# ### 2.USING VarianceThreshold FROM SKLEARN

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
varr_thresh=VarianceThreshold(threshold=0.1)
varr_thresh.fit_transform(df)
selected_columns = df.columns[varr_thresh.get_support()]
selected_columns
# Out:
# Index(['SalePrice'], dtype='object')

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(100,500):
    varr_thresh=VarianceThreshold(threshold=i/100000)
    varr_thresh.fit_transform(df.iloc[:,:-1])
    selected_columns = df.iloc[:,:-1].columns[varr_thresh.get_support()]
    df_fs=create_df(selected_columns)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic
# Out:
#        K           MAE          RMSE        r2
# 0    100  24423.850569  42203.972512  0.767784
# 1    101  24423.850569  42203.972512  0.767784
# 2    102  24109.734948  41004.925139  0.780791
# 3    103  24109.734948  41004.925139  0.780791
# 4    104  24109.734948  41004.925139  0.780791
# ..   ...           ...           ...       ...
# 395  495  47344.497336  75372.919152  0.259344
# 396  496  47344.497336  75372.919152  0.259344
# 397  497  47344.497336  75372.919152  0.259344
# 398  498  47344.497336  75372.919152  0.259344
# 399  499  47344.497336  75372.919152  0.259344
#
# [400 rows x 4 columns]

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#        K           MAE          RMSE        r2
# 2    102  24109.734948  41004.925139  0.780791
# 3    103  24109.734948  41004.925139  0.780791
# 4    104  24109.734948  41004.925139  0.780791
# 11   111  24414.903479  41786.379721  0.772356
# 13   113  24414.903479  41786.379721  0.772356
# ..   ...           ...           ...       ...
# 373  473  47344.497336  75372.919152  0.259344
# 372  472  47344.497336  75372.919152  0.259344
# 398  498  47344.497336  75372.919152  0.259344
# 384  484  47344.497336  75372.919152  0.259344
# 399  499  47344.497336  75372.919152  0.259344
#
# [400 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x=statistic["K"]/1000,y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x=statistic["K"]/1000,y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\873788412.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\873788412.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### Univariate feature selection

# %% [markdown]
# ### Statistic function (r_regression, f_regression, mutual_info_regression)

# %% [markdown]
# ### 1. r_regression

# %% [markdown]
# ![image.png](attachment:f483b42b-de90-46a8-afcd-444eb978b015.png)

# %% [markdown]
# ### Using numpy

# %%
def similitary_score(x,y):
    x_avg=np.average(x)
    y_avg=np.average(y)
    up=np.sum((x-x_avg)*(y-y_avg))
    down=np.sqrt(np.sum((x-x_avg)**2)*np.sum((y-y_avg)**2))
    return up/down

# %%
print(similitary_score(df["OverallQual"],df["SalePrice"]))
# Out:
# 0.48821565211312173

# %%
top_feature=[]
for col in df.columns:
    score=similitary_score(df[col],df["SalePrice"])
    if col != "SalePrice" and score > 0.6:
        top_feature.append([col,score])
top_feature
# Out:
# []

# %% [markdown]
# ### Using sklearn

# %%
from sklearn.feature_selection import r_regression
from sklearn.feature_selection import SelectKBest
# for i in range(5,21):
fs=SelectKBest(r_regression,k=6)
fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
# selected=df.columns[fs.get_support()]
fs.get_feature_names_out()
# Out:
# array(['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#        'GarageCars', 'GarageArea'], dtype=object)

# %%
k, mae, rmse, r2 = [], [], [], []

for i in range(5,120):
    fs=SelectKBest(r_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic.to_csv("r_regression_label_enc.csv")
statistic
# Out:
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=75 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=76 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=77 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=78 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=79 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=80 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=81 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=82 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=83 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=84 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=85 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=86 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=87 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=88 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=89 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=90 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=91 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=92 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=93 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=94 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=95 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=96 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=97 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=98 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=99 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=100 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=101 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=102 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=103 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=104 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=105 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=106 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=107 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=108 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=109 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=110 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=111 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=112 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=113 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=114 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=115 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=116 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=117 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=118 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=119 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
#        K           MAE          RMSE        r2
# 0      5  28933.237037  52049.752653  0.646798
# 1      6  28846.814239  50890.727924  0.662353
# 2      7  30234.295483  51642.434614  0.652304
# 3      8  29206.492384  50298.746438  0.670162
# 4      9  30501.199485  51284.725739  0.657104
# ..   ...           ...           ...       ...
# 110  115  22886.119419  41310.872121  0.777508
# 111  116  22886.119419  41310.872121  0.777508
# 112  117  22886.119419  41310.872121  0.777508
# 113  118  22886.119419  41310.872121  0.777508
# 114  119  22886.119419  41310.872121  0.777508
#
# [115 rows x 4 columns]

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#        K           MAE          RMSE        r2
# 114  119  22886.119419  41310.872121  0.777508
# 89    94  22886.119419  41310.872121  0.777508
# 88    93  22886.119419  41310.872121  0.777508
# 87    92  22886.119419  41310.872121  0.777508
# 86    91  22886.119419  41310.872121  0.777508
# ..   ...           ...           ...       ...
# 0      5  28933.237037  52049.752653  0.646798
# 5     10  29202.203612  49952.213899  0.674691
# 3      8  29206.492384  50298.746438  0.670162
# 2      7  30234.295483  51642.434614  0.652304
# 4      9  30501.199485  51284.725739  0.657104
#
# [115 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### 2.f_regression

# %% [markdown]
# ![image.png](attachment:95f14443-0240-442c-b294-562b150eb8bd.png)

# %% [markdown]
# ![image.png](attachment:a344f6dc-6cf9-490d-a595-9c80c9c1128a.png)

# %%
from sklearn.feature_selection import f_regression

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(5,120):
    fs=SelectKBest(f_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic.to_csv("f_regression_label_enc.csv")
statistic
# Out:
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=75 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=76 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=77 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=78 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=79 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=80 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=81 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=82 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=83 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=84 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=85 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=86 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=87 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=88 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=89 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=90 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=91 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=92 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=93 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=94 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=95 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=96 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=97 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=98 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=99 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=100 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=101 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=102 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=103 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=104 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=105 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=106 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=107 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=108 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=109 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=110 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=111 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=112 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=113 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=114 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=115 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=116 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=117 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=118 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=119 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
#        K           MAE          RMSE        r2
# 0      5  27743.818204  44232.610932  0.744923
# 1      6  27298.811565  42772.990683  0.761480
# 2      7  26440.608987  42928.430110  0.759743
# 3      8  26265.865312  42679.336745  0.762523
# 4      9  26215.940874  42938.179945  0.759634
# ..   ...           ...           ...       ...
# 110  115  22886.119419  41310.872121  0.777508
# 111  116  22886.119419  41310.872121  0.777508
# 112  117  22886.119419  41310.872121  0.777508
# 113  118  22886.119419  41310.872121  0.777508
# 114  119  22886.119419  41310.872121  0.777508
#
# [115 rows x 4 columns]

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#      K           MAE          RMSE        r2
# 29  34  22402.391868  39224.689533  0.799412
# 34  39  22488.826106  38539.774416  0.806356
# 35  40  22559.142822  38297.471213  0.808783
# 28  33  22565.508065  39195.982000  0.799705
# 32  37  22583.089202  39207.784308  0.799585
# ..  ..           ...           ...       ...
# 2    7  26440.608987  42928.430110  0.759743
# 6   11  26529.555768  42873.533570  0.760357
# 5   10  26627.478714  43116.211946  0.757636
# 1    6  27298.811565  42772.990683  0.761480
# 0    5  27743.818204  44232.610932  0.744923
#
# [115 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### 3.Mutual infomation

# %% [markdown]
# ### Fomula

# %% [markdown]
# ![image.png](attachment:283a97b8-8534-4c70-8086-d6b229834262.png)

# %% [markdown]
# ### Mesure dependency of 2 variable X,Y

# %% [markdown]
# ### KDE method (Estimate Probability Density Function)

# %% [markdown]
# ![image.png](attachment:d3173b36-c1e3-421a-a817-095dbfd9041c.png)

# %% [markdown]
# ![image.png](attachment:88044c6a-ccc1-4d54-bbb2-f410d59aa145.png)

# %% [markdown]
# ![image.png](attachment:5c8079a5-deea-43ef-85ff-0e46935b227e.png)

# %%
all_col=df.columns
all_col
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'Ageofhouse',
#        'SalePrice'],
#       dtype='object')

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
k, mae, rmse, r2 = [], [], [], []
for i in range(5,120):
    fs=SelectKBest(mutual_info_regression,k=i)
    fl_df=fs.fit_transform(df.iloc[:,:-1],df.iloc[:,-1])
    c=fs.get_feature_names_out()
    df_fs=create_df(c)
    eval(df_fs)
statistic_tup={
    "K":k,
    "MAE":mae,
    "RMSE":rmse,
    "r2":r2
}
statistic=pd.DataFrame(statistic_tup)
statistic
# Out:
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=75 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=76 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=77 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=78 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=79 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=80 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=81 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=82 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=83 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=84 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=85 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=86 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=87 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=88 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=89 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=90 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=91 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=92 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=93 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=94 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=95 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=96 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=97 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=98 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=99 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=100 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=101 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=102 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=103 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=104 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=105 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=106 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=107 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=108 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=109 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=110 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=111 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=112 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=113 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=114 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=115 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=116 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=117 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=118 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
# D:\miniconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=119 is greater than n_features=74. All the features will be returned.
#   warnings.warn(
#        K           MAE          RMSE        r2
# 0      5  31434.501667  49044.858269  0.686402
# 1      6  30799.519656  49007.244384  0.686883
# 2      7  29978.117774  48829.010634  0.689156
# 3      8  29003.314491  47655.390018  0.703919
# 4      9  29034.897864  46731.781015  0.715285
# ..   ...           ...           ...       ...
# 110  115  22886.119419  41310.872121  0.777508
# 111  116  22886.119419  41310.872121  0.777508
# 112  117  22886.119419  41310.872121  0.777508
# 113  118  22886.119419  41310.872121  0.777508
# 114  119  22886.119419  41310.872121  0.777508
#
# [115 rows x 4 columns]

# %%
statistic.to_csv("mutual_infomation_label_enc.csv")

# %%
statistic.sort_values("MAE",ascending=True)
# Out:
#        K           MAE          RMSE        r2
# 52    57  22806.789117  41148.475729  0.779254
# 49    54  22813.225269  40512.922067  0.786020
# 114  119  22886.119419  41310.872121  0.777508
# 86    91  22886.119419  41310.872121  0.777508
# 85    90  22886.119419  41310.872121  0.777508
# ..   ...           ...           ...       ...
# 4      9  29034.897864  46731.781015  0.715285
# 5     10  29238.419871  47200.466814  0.709545
# 2      7  29978.117774  48829.010634  0.689156
# 1      6  30799.519656  49007.244384  0.686883
# 0      5  31434.501667  49044.858269  0.686402
#
# [115 rows x 4 columns]

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
plt.show()
# Out:
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\3627608168.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# C:\Users\NTCUONG\AppData\Local\Temp\ipykernel_6020\3627608168.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")

# %% [markdown]
# ### RFE (Recursive feature elimination)

# %% [markdown]
# df

# %% [markdown]
# from sklearn.feature_selection import RFE,RFECV
# rfe=RFE(estimator=model,n_features_to_select=5)
# rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
# rfe.get_feature_names_out()

# %% [markdown]
# k, mae, rmse, r2 = [], [], [], []
# for i in range(10,50):
#     rfe=RFE(estimator=model,n_features_to_select=i)
#     rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
#     c = df.iloc[:,:-1].columns[rfe.support_]
#     df_fs=create_df(c)
#     eval(df_fs)
# statistic_tup={
#     "K":k,
#     "MAE":mae,
#     "RMSE":rmse,
#     "r2":r2
# }
# statistic=pd.DataFrame(statistic_tup)
# statistic

# %% [markdown]
# statistic.to_csv("RFE.csv")

# %% [markdown]
# statistic=pd.read_csv("RFE.csv")

# %% [markdown]
# fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
# ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
# ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
# ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
# plt.show()

# %% [markdown]
# k, mae, rmse, r2 = [], [], [], []
# for i in range(10,15):
#     rfe=RFECV(estimator=model,min_features_to_select=i,cv=5)
#     rfe.fit(df.iloc[:,:-1],df.iloc[:,-1])
#     c = df.iloc[:,:-1].columns[rfe.support_]
#     df_fs=create_df(c)
#     eval(df_fs)
# statistic_tup={
#     "K":k,
#     "MAE":mae,
#     "RMSE":rmse,
#     "r2":r2
# }
# statistic=pd.DataFrame(statistic_tup)
# statistic

# %% [markdown]
# fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
# ax1=sns.lineplot(data=statistic,x="K",y="MAE",ax=axes[0])
# ax2=sns.lineplot(data=statistic,x="K",y="r2",ax=axes[1])
# ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, ha="left")
# ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90, ha="left")
# plt.show()

# %% [markdown]
# statistic.to_csv("RFECV.csv")

# %%
r=pd.read_csv("r_regression_label_enc.csv")
r=r.iloc[:,1:]
r
# Out:
#        K           MAE          RMSE        r2
# 0      5  28933.237037  52049.752653  0.646798
# 1      6  28846.814239  50890.727924  0.662353
# 2      7  30234.295483  51642.434614  0.652304
# 3      8  29206.492384  50298.746438  0.670162
# 4      9  30501.199485  51284.725739  0.657104
# ..   ...           ...           ...       ...
# 110  115  22886.119419  41310.872121  0.777508
# 111  116  22886.119419  41310.872121  0.777508
# 112  117  22886.119419  41310.872121  0.777508
# 113  118  22886.119419  41310.872121  0.777508
# 114  119  22886.119419  41310.872121  0.777508
#
# [115 rows x 4 columns]

# %%
f=pd.read_csv("f_regression_label_enc.csv")
f=f.iloc[:,1:]
f
# Out:
#        K           MAE          RMSE        r2
# 0      5  27743.818204  44232.610932  0.744923
# 1      6  27298.811565  42772.990683  0.761480
# 2      7  26440.608987  42928.430110  0.759743
# 3      8  26265.865312  42679.336745  0.762523
# 4      9  26215.940874  42938.179945  0.759634
# ..   ...           ...           ...       ...
# 110  115  22886.119419  41310.872121  0.777508
# 111  116  22886.119419  41310.872121  0.777508
# 112  117  22886.119419  41310.872121  0.777508
# 113  118  22886.119419  41310.872121  0.777508
# 114  119  22886.119419  41310.872121  0.777508
#
# [115 rows x 4 columns]

# %%
mutual=pd.read_csv("mutual_infomation_label_enc.csv")
mutual=mutual.iloc[:,1:]
mutual
# Out:
#        K           MAE          RMSE        r2
# 0      5  31434.501667  49044.858269  0.686402
# 1      6  30799.519656  49007.244384  0.686883
# 2      7  29978.117774  48829.010634  0.689156
# 3      8  29003.314491  47655.390018  0.703919
# 4      9  29034.897864  46731.781015  0.715285
# ..   ...           ...           ...       ...
# 110  115  22886.119419  41310.872121  0.777508
# 111  116  22886.119419  41310.872121  0.777508
# 112  117  22886.119419  41310.872121  0.777508
# 113  118  22886.119419  41310.872121  0.777508
# 114  119  22886.119419  41310.872121  0.777508
#
# [115 rows x 4 columns]

# %%
joint=pd.merge(r,f,how='inner',on="K")
joint
# Out:
#        K         MAE_x        RMSE_x      r2_x         MAE_y        RMSE_y  \
# 0      5  28933.237037  52049.752653  0.646798  27743.818204  44232.610932
# 1      6  28846.814239  50890.727924  0.662353  27298.811565  42772.990683
# 2      7  30234.295483  51642.434614  0.652304  26440.608987  42928.430110
# 3      8  29206.492384  50298.746438  0.670162  26265.865312  42679.336745
# 4      9  30501.199485  51284.725739  0.657104  26215.940874  42938.179945
# ..   ...           ...           ...       ...           ...           ...
# 110  115  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
# 111  116  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
# 112  117  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
# 113  118  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
# 114  119  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
#
#          r2_y
# 0    0.744923
# 1    0.761480
# 2    0.759743
# 3    0.762523
# 4    0.759634
# ..        ...
# 110  0.777508
# 111  0.777508
# 112  0.777508
# 113  0.777508
# 114  0.777508
#
# [115 rows x 7 columns]

# %%
joint=pd.merge(joint,mutual,on="K",how="inner")
joint
# Out:
#        K         MAE_x        RMSE_x      r2_x         MAE_y        RMSE_y  \
# 0      5  28933.237037  52049.752653  0.646798  27743.818204  44232.610932
# 1      6  28846.814239  50890.727924  0.662353  27298.811565  42772.990683
# 2      7  30234.295483  51642.434614  0.652304  26440.608987  42928.430110
# 3      8  29206.492384  50298.746438  0.670162  26265.865312  42679.336745
# 4      9  30501.199485  51284.725739  0.657104  26215.940874  42938.179945
# ..   ...           ...           ...       ...           ...           ...
# 110  115  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
# 111  116  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
# 112  117  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
# 113  118  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
# 114  119  22886.119419  41310.872121  0.777508  22886.119419  41310.872121
#
#          r2_y           MAE          RMSE        r2
# 0    0.744923  31434.501667  49044.858269  0.686402
# 1    0.761480  30799.519656  49007.244384  0.686883
# 2    0.759743  29978.117774  48829.010634  0.689156
# 3    0.762523  29003.314491  47655.390018  0.703919
# 4    0.759634  29034.897864  46731.781015  0.715285
# ..        ...           ...           ...       ...
# 110  0.777508  22886.119419  41310.872121  0.777508
# 111  0.777508  22886.119419  41310.872121  0.777508
# 112  0.777508  22886.119419  41310.872121  0.777508
# 113  0.777508  22886.119419  41310.872121  0.777508
# 114  0.777508  22886.119419  41310.872121  0.777508
#
# [115 rows x 10 columns]

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(joint["K"],joint["MAE_x"],label="r_regression")
plt.plot(joint["K"],joint["MAE_y"],label="f_regression")
plt.plot(joint["K"],joint["MAE"],label="mutual_infomation")
plt.xlabel("Number of feature")
plt.ylabel("MAE")
plt.title("MAE evaluation") 
plt.legend()
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(joint["K"],joint["r2_x"],label="r_regression")
plt.plot(joint["K"],joint["r2_y"],label="f_regression")
plt.plot(joint["K"],joint["r2"],label="mutual_infomation")
plt.xlabel("Number of feature")
plt.ylabel("MAE")
plt.title("R2 evaluation") 
plt.legend()
