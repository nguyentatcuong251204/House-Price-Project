# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("StatisticModel.csv")
df
# Out:
#               Model  feature_selection  NOF        Scaler        Encoder  \
# 0    RandomForestRG  VarianceThreshold  100           NaN   LabelEncoder
# 1    RandomForestRG  VarianceThreshold  110           NaN   LabelEncoder
# 2    RandomForestRG  VarianceThreshold  120           NaN   LabelEncoder
# 3    RandomForestRG  VarianceThreshold  130           NaN   LabelEncoder
# 4    RandomForestRG  VarianceThreshold  140           NaN   LabelEncoder
# ..              ...                ...  ...           ...            ...
# 619  RandomForestRG                UFS   75  Minmaxscaler  OnehotEncoder
# 620  RandomForestRG                UFS   85  Minmaxscaler  OnehotEncoder
# 621  RandomForestRG                UFS   95  Minmaxscaler  OnehotEncoder
# 622  RandomForestRG                UFS  105  Minmaxscaler  OnehotEncoder
# 623  RandomForestRG                UFS  115  Minmaxscaler  OnehotEncoder
#
#            Imputer        R2           MAE
# 0    SimpleImputer  0.899291  17306.782705
# 1    SimpleImputer  0.893694  17499.186747
# 2    SimpleImputer  0.893885  17543.264452
# 3    SimpleImputer  0.894416  17768.785993
# 4    SimpleImputer  0.893008  17419.923048
# ..             ...       ...           ...
# 619     KnnImputer  0.881730  18819.958699
# 620     KnnImputer  0.883652  18647.069623
# 621     KnnImputer  0.885516  18543.017877
# 622     KnnImputer  0.885817  18733.668767
# 623     KnnImputer  0.887743  18367.988493
#
# [624 rows x 8 columns]

# %%
df["Scaler"]=df["Scaler"].fillna("None")
df["Imputer"]=df["Imputer"].apply(lambda x:"SimpleImputer" if x=="Simpleimputer" else x)

# %%
df.sort_values("R2",ascending=False)
# Out:
#               Model  feature_selection  NOF      Scaler        Encoder  \
# 19   RandomForestRG  VarianceThreshold  290        None   LabelEncoder
# 46   RandomForestRG                UFS   65        None   LabelEncoder
# 0    RandomForestRG  VarianceThreshold  100        None   LabelEncoder
# 355  RandomForestRG                UFS   35        None  OnehotEncoder
# 21   RandomForestRG  VarianceThreshold  310        None   LabelEncoder
# ..              ...                ...  ...         ...            ...
# 245  RandomForestRG  VarianceThreshold  470  Normalizer   LabelEncoder
# 559  RandomForestRG  VarianceThreshold  490  Normalizer  OnehotEncoder
# 244  RandomForestRG  VarianceThreshold  460  Normalizer   LabelEncoder
# 247  RandomForestRG  VarianceThreshold  490  Normalizer   LabelEncoder
# 246  RandomForestRG  VarianceThreshold  480  Normalizer   LabelEncoder
#
#            Imputer        R2           MAE
# 19   SimpleImputer  0.900975  17199.952295
# 46   SimpleImputer  0.899722  17175.904007
# 0    SimpleImputer  0.899291  17306.782705
# 355  SimpleImputer  0.899190  17406.955822
# 21   SimpleImputer  0.898470  17166.774760
# ..             ...       ...           ...
# 245     KnnImputer  0.548163  36709.797192
# 559     KnnImputer  0.539599  38377.471233
# 244     KnnImputer  0.531835  37272.177158
# 247     KnnImputer  0.288148  46696.058185
# 246     KnnImputer  0.283048  46993.345788
#
# [624 rows x 8 columns]

# %% [markdown]
# # Distribution of R2 Score

# %%
sns.histplot(data=df,x="R2")
# Out:
# <Axes: xlabel='R2', ylabel='Count'>

# %% [markdown]
# # R2 score depend on UFS

# %%
sns.scatterplot(data=df.loc[(df["feature_selection"]=="UFS")],x="NOF",y="R2",hue="Scaler")
plt.xlabel("Number of feature")
# Out:
# Text(0.5, 0, 'Number of feature')

# %%
sns.boxplot(data=df.loc[(df["feature_selection"]=="UFS")],x="NOF",y="R2")
# Out:
# <Axes: xlabel='NOF', ylabel='R2'>

# %%
def find(nof,feature):
    maxr2_for_each_NOF=df.loc[(df["feature_selection"]==feature)].loc[(df["NOF"]==nof)]
    maxr2_for_each_NOF=maxr2_for_each_NOF.sort_values("R2",ascending=False).head(1)
    return maxr2_for_each_NOF

# %%
maxr2_for_each_NOF=find(5,"UFS")
for i in range(6,121):
    maxr2_for_each_NOF=pd.concat([maxr2_for_each_NOF,find(i,"UFS")])
maxr2_for_each_NOF
# Out:
#               Model feature_selection  NOF Scaler        Encoder  \
# 40   RandomForestRG               UFS    5   None   LabelEncoder
# 41   RandomForestRG               UFS   15   None   LabelEncoder
# 354  RandomForestRG               UFS   25   None  OnehotEncoder
# 355  RandomForestRG               UFS   35   None  OnehotEncoder
# 356  RandomForestRG               UFS   45   None  OnehotEncoder
# 357  RandomForestRG               UFS   55   None  OnehotEncoder
# 46   RandomForestRG               UFS   65   None   LabelEncoder
# 47   RandomForestRG               UFS   75   None   LabelEncoder
# 360  RandomForestRG               UFS   85   None  OnehotEncoder
# 361  RandomForestRG               UFS   95   None  OnehotEncoder
# 362  RandomForestRG               UFS  105   None  OnehotEncoder
# 51   RandomForestRG               UFS  115   None   LabelEncoder
#
#            Imputer        R2           MAE
# 40   SimpleImputer  0.874564  19551.883676
# 41   SimpleImputer  0.890632  18533.221705
# 354  SimpleImputer  0.895757  18031.708590
# 355  SimpleImputer  0.899190  17406.955822
# 356  SimpleImputer  0.896256  17344.166473
# 357  SimpleImputer  0.895975  17434.162900
# 46   SimpleImputer  0.899722  17175.904007
# 47   SimpleImputer  0.893155  17324.002945
# 360  SimpleImputer  0.898112  17298.916027
# 361  SimpleImputer  0.896080  17382.623733
# 362  SimpleImputer  0.892448  17560.767534
# 51   SimpleImputer  0.895671  17527.990993

# %% [markdown]
# # Max R2 for each NOF

# %%
sns.lineplot(data=maxr2_for_each_NOF,x="NOF",y="R2",color="green")
# Out:
# <Axes: xlabel='NOF', ylabel='R2'>

# %%
maxr2_for_each_thresh=find(100,"VarianceThreshold")
for i in range(101,501):
    maxr2_for_each_thresh=pd.concat([maxr2_for_each_thresh,find(i,"VarianceThreshold")])
maxr2_for_each_thresh
# Out:
#               Model  feature_selection  NOF Scaler        Encoder  \
# 0    RandomForestRG  VarianceThreshold  100   None   LabelEncoder
# 313  RandomForestRG  VarianceThreshold  110   None  OnehotEncoder
# 2    RandomForestRG  VarianceThreshold  120   None   LabelEncoder
# 3    RandomForestRG  VarianceThreshold  130   None   LabelEncoder
# 4    RandomForestRG  VarianceThreshold  140   None   LabelEncoder
# 5    RandomForestRG  VarianceThreshold  150   None   LabelEncoder
# 318  RandomForestRG  VarianceThreshold  160   None  OnehotEncoder
# 319  RandomForestRG  VarianceThreshold  170   None  OnehotEncoder
# 320  RandomForestRG  VarianceThreshold  180   None  OnehotEncoder
# 9    RandomForestRG  VarianceThreshold  190   None   LabelEncoder
# 10   RandomForestRG  VarianceThreshold  200   None   LabelEncoder
# 11   RandomForestRG  VarianceThreshold  210   None   LabelEncoder
# 12   RandomForestRG  VarianceThreshold  220   None   LabelEncoder
# 13   RandomForestRG  VarianceThreshold  230   None   LabelEncoder
# 14   RandomForestRG  VarianceThreshold  240   None   LabelEncoder
# 15   RandomForestRG  VarianceThreshold  250   None   LabelEncoder
# 16   RandomForestRG  VarianceThreshold  260   None   LabelEncoder
# 329  RandomForestRG  VarianceThreshold  270   None  OnehotEncoder
# 330  RandomForestRG  VarianceThreshold  280   None  OnehotEncoder
# 19   RandomForestRG  VarianceThreshold  290   None   LabelEncoder
# 332  RandomForestRG  VarianceThreshold  300   None  OnehotEncoder
# 21   RandomForestRG  VarianceThreshold  310   None   LabelEncoder
# 334  RandomForestRG  VarianceThreshold  320   None  OnehotEncoder
# 335  RandomForestRG  VarianceThreshold  330   None  OnehotEncoder
# 24   RandomForestRG  VarianceThreshold  340   None   LabelEncoder
# 337  RandomForestRG  VarianceThreshold  350   None  OnehotEncoder
# 26   RandomForestRG  VarianceThreshold  360   None   LabelEncoder
# 27   RandomForestRG  VarianceThreshold  370   None   LabelEncoder
# 28   RandomForestRG  VarianceThreshold  380   None   LabelEncoder
# 341  RandomForestRG  VarianceThreshold  390   None  OnehotEncoder
# 30   RandomForestRG  VarianceThreshold  400   None   LabelEncoder
# 31   RandomForestRG  VarianceThreshold  410   None   LabelEncoder
# 32   RandomForestRG  VarianceThreshold  420   None   LabelEncoder
# 33   RandomForestRG  VarianceThreshold  430   None   LabelEncoder
# 34   RandomForestRG  VarianceThreshold  440   None   LabelEncoder
# 35   RandomForestRG  VarianceThreshold  450   None   LabelEncoder
# 36   RandomForestRG  VarianceThreshold  460   None   LabelEncoder
# 37   RandomForestRG  VarianceThreshold  470   None   LabelEncoder
# 350  RandomForestRG  VarianceThreshold  480   None  OnehotEncoder
# 351  RandomForestRG  VarianceThreshold  490   None  OnehotEncoder
#
#            Imputer        R2           MAE
# 0    SimpleImputer  0.899291  17306.782705
# 313  SimpleImputer  0.893928  17340.080856
# 2    SimpleImputer  0.893885  17543.264452
# 3    SimpleImputer  0.894416  17768.785993
# 4    SimpleImputer  0.893008  17419.923048
# 5    SimpleImputer  0.888940  17686.165171
# 318  SimpleImputer  0.890601  17527.651370
# 319  SimpleImputer  0.894298  17499.413596
# 320  SimpleImputer  0.891997  17555.176644
# 9    SimpleImputer  0.891439  17717.296610
# 10   SimpleImputer  0.891908  17827.499144
# 11   SimpleImputer  0.890145  17430.567226
# 12   SimpleImputer  0.892898  17523.059041
# 13   SimpleImputer  0.895847  17467.507329
# 14   SimpleImputer  0.892457  17727.240171
# 15   SimpleImputer  0.893659  17466.659212
# 16   SimpleImputer  0.890776  17480.568699
# 329  SimpleImputer  0.898150  17437.566473
# 330  SimpleImputer  0.893797  17676.840103
# 19   SimpleImputer  0.900975  17199.952295
# 332  SimpleImputer  0.888166  17770.728664
# 21   SimpleImputer  0.898470  17166.774760
# 334  SimpleImputer  0.892217  17616.641541
# 335  SimpleImputer  0.896772  17315.147911
# 24   SimpleImputer  0.895414  17764.872260
# 337  SimpleImputer  0.894018  17348.160411
# 26   SimpleImputer  0.895331  17378.884178
# 27   SimpleImputer  0.889498  17860.630068
# 28   SimpleImputer  0.894366  17602.251781
# 341  SimpleImputer  0.894271  17517.800445
# 30   SimpleImputer  0.891458  17570.727945
# 31   SimpleImputer  0.891355  17590.784932
# 32   SimpleImputer  0.895331  17498.807842
# 33   SimpleImputer  0.896947  17170.594212
# 34   SimpleImputer  0.889123  17650.064247
# 35   SimpleImputer  0.897753  17217.631610
# 36   SimpleImputer  0.892239  17636.237055
# 37   SimpleImputer  0.893047  17559.432055
# 350  SimpleImputer  0.892504  17498.007432
# 351  SimpleImputer  0.891112  17603.905925

# %%
sns.lineplot(data=maxr2_for_each_thresh,x=df["NOF"]/100000,y="R2",color="green")
plt.xlabel("Threshold")
# Out:
# Text(0.5, 0, 'Threshold')

# %% [markdown]
# # R2 score depend on Variance Threshold

# %%
sns.scatterplot(data=df.loc[(df["feature_selection"]=="VarianceThreshold")],x=df["NOF"]/100000,y="R2",hue="Scaler")
plt.xlabel("Threshold")
# Out:
# Text(0.5, 0, 'Threshold')

# %% [markdown]
# # R2 depend on Scaler

# %%
sns.boxplot(data=df, x="Scaler",y="R2")
# Out:
# <Axes: xlabel='Scaler', ylabel='R2'>

# %% [markdown]
# # R2 depend on Imputer

# %%
sns.boxplot(data=df,x="Imputer",y="R2")
# Out:
# <Axes: xlabel='Imputer', ylabel='R2'>

# %%
sns.boxplot(data=df,x="Encoder",y="R2")
# Out:
# <Axes: xlabel='Encoder', ylabel='R2'>
